# %% [markdown]
# ![Matplotlib](img/matplotlib.png)

# %% [markdown]
# # Introduction

# %% [markdown]
# Dans ce notebook, vous allez apprendre à utiliser **Matplotlib**, une bibliothèque incontournable en Python pour **visualiser des données**.
#
# La visualisation est une compétence fondamentale en **data science**. Elle permet :
# - d'explorer les données pour détecter des motifs, anomalies ou corrélations,
# - de guider la prise de décision sur le nettoyage, les transformations ou le choix des modèles,
# - de communiquer les résultats de vos analyses ou prédictions à des non-techniciens,
# - de produire des livrables compréhensibles pour des experts métier ou des commanditaires.
#
# Les compétences que vous allez développer ici vous serviront tout au long de vos projets data, notamment lors des phases de **data exploration** et de **présentation des résultats**.

# %% [markdown]
# # 1. 📊 Pourquoi visualiser des données ?

# %% [markdown]
# En **data science**, la première étape après l'import d'un jeu de données est souvent une phase d'observation. Visualiser les données vous permet de :
# - repérer des tendances globales (croissance, saisonnalité...),
# - identifier des valeurs aberrantes ou manquantes,
# - orienter votre choix d'algorithmes ou de pré-traitements.

# %% [markdown]
# ### Ce que vous allez faire ici
# - Prendre en main `matplotlib.pyplot`
# - Tracer une courbe simple (ex : évolution d’un capital)
# - Ajouter un titre, des axes, une légende et une grille

# %% [markdown]
# ### Cas concret
# Vous pouvez explorer la courbe de variation d'une variable numérique dans un jeu de données (ex : température journalière, revenu mensuel, stock d’un produit).
#
# Ci-dessous, un exemple d'une visualisation de l'évolution d'un compte d'épargne fictif.

# %%
import matplotlib.pyplot as plt

# Création d'une liste d'années allant de 1 à 10
annees = list(range(1, 11)) 

# Calcul du solde du compte épargne pour chaque année, avec un taux d’intérêt de 5 % par an
# Formule utilisée : capital initial (1000 €) * (1.05)^nombre d'années
solde = [1000 * (1.05)**i for i in annees]      
solde_2 = [1000 * (1.03)**i for i in annees]      

# Tracé de la courbe représentant l'évolution de l'épargne,
# avec une étiquette ("label") qui sera utilisée dans la légende du graphique
# ℹ️ il est possible d'ajouter plusieurs courbes sur le même schéma en appelant la méthode .plot() pour chaque  courbe.
plt.plot(annees, solde, label="Épargne (5%/an)")

# Ajout du label de l’axe des x (les années)
plt.xlabel("Années")

# Ajout du label de l’axe des y (le solde en euros)
plt.ylabel("Solde (€)")

# Titre du graphique
plt.title("Évolution de l'épargne sur 10 ans") 

# Affichage de la légende pour identifier la courbe
plt.legend()

# Affichage d’une grille pour faciliter la lecture du graphique
plt.grid(True)

# Affichage du graphique final
plt.show()

# %% [markdown]
# ### 🧩 Exercice

# %% [markdown]
# Reprenez le code précédent et réalisez un nouveau graphique sur un autre thème de votre choix (par exemple : évolution de la population, températures mensuelles, ventes annuelles, etc.).
#
# Votre graphique devra :
# - contenir au moins deux courbes
# - utiliser des légendes explicites
# - comporter un titre principal adapté au thème choisi
# - avoir des étiquettes d’axes
# - afficher une grille pour améliorer la lisibilité
# - utiliser une légende pour identifier les courbes
#
# 💡 Vous pouvez vous inspirer du modèle précédent et adapter les données selon le thème choisi.

# %%
import matplotlib.ticker as ticker

# Création d'une liste d'années allant de 1 à 10
annees = list(range(1, 11)) 

# Calcul du solde du compte épargne pour chaque année, avec un taux d’intérêt de 5 % par an
# Formule utilisée : capital initial (1000 €) * (1.05)^nombre d'années
population = [200000 * (1.15)**i for i in annees]      
naissance = [12000 * (1.6)**i for i in annees]      

# Tracé de la courbe représentant l'évolution de l'épargne,
# avec une étiquette ("label") qui sera utilisée dans la légende du graphique
# ℹ️ il est possible d'ajouter plusieurs courbes sur le même schéma en appelant la méthode .plot() pour chaque  courbe.
plt.plot(annees, population, label="Population")
plt.plot(annees, naissance, label="Naissances")

# Ajout du label de l’axe des x (les années)
plt.xlabel("Années")

# Ajout du label de l’axe des y (le solde en euros)
plt.ylabel("Population/Naissances")

# Titre du graphique
plt.title("Évolution de la démographie sur 10 ans") 

# Affichage de la légende pour identifier la courbe
plt.legend()

# Affichage d’une grille pour faciliter la lecture du graphique
plt.grid(True)

# Forcer l'affichage des unités
plt.gca().yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, _: f'{int(x):,}'))

# Affichage du graphique final
plt.show()

# %% [markdown]
# # 2. 📈 Utiliser le bon type de graphique

# %% [markdown]
# En **exploration de données**, le type de graphique utilisé dépend de la nature des données

# %% [markdown]
# ### 2.1. Pour les **données quantitatives**

# %% [markdown]
# #### a. Courbe (line plot)

# %% [markdown]
# Un graphique en courbe est particulièrement adapté pour suivre l’évolution d’une variable dans le temps, car il permet de visualiser les tendances, les hausses et les baisses de manière continue.

# %% [markdown]
# *(voir les graphiques précédents)*

# %% [markdown]
# #### b. Histogramme

# %% [markdown]
# Un histogramme est utilisé pour observer la distribution d’une variable continue, comme la taille ou le revenu, afin de visualiser comment les valeurs se répartissent sur différents intervalles.

# %%
# Liste des notes obtenues par des élèves
notes = [12, 15, 14, 17, 10, 11, 18, 13, 14, 15, 16, 8, 12, 13, 16, 7, 8, 10, 12]

# Création de l'histogramme :
# - bins=5 : nombre d'intervalles pour regrouper les notes
# - rwidth=0.8 : largeur relative des barres (pour laisser de l'espace entre elles)
plt.hist(notes, bins=5, rwidth=0.8)

# Ajout du titre du graphique
plt.title("Distribution des notes")

# Étiquette de l'axe des x : les classes de notes
plt.xlabel("Notes")

# Étiquette de l'axe des y : nombre d'élèves par intervalle de notes
plt.ylabel("Fréquence")

# Affichage du graphique
plt.show()

# %% [markdown]
# ### 2.2. Pour les **données catégorielles**

# %% [markdown]
# #### a. Diagramme en barres (bar plot)

# %% [markdown]
# On utilise un diagramme en barres pour comparer le nombre d’observations entre différentes catégories, par exemple le nombre de clients par région ou les ventes enregistrées chaque mois.

# %%
# Données : noms des mois
mois = ["Jan", "Fév", "Mar", "Avr", "Mai"]

# Données : nombre de ventes correspondantes à chaque mois
ventes = [100, 150, 90, 200, 130]

# Création d’un diagramme en barres pour visualiser les ventes par mois
plt.bar(mois, ventes)

# Ajout d’un titre au graphique
plt.title("Ventes mensuelles")

# Affichage du graphique
plt.show()

# %% [markdown]
# **Camembert (pie chart)** : pour visualiser la répartition d’une variable qualitative (ex : répartition des ventes par produit).

# %%
# Définition des parts de marché en pourcentage
parts = [40, 30, 20, 10]

# Étiquettes correspondant à chaque part (nom des entreprises)
labels = ['Entreprise A', 'B', 'C', 'D']

# Création du graphique en camembert (pie chart)
# - labels : pour afficher les noms des entreprises
# - autopct : pour afficher les pourcentages avec une décimale
plt.pie(parts, labels=labels, autopct='%1.1f%%')

# Ajout d’un titre au graphique
plt.title("Parts de marché")

# Affichage du graphique
plt.show()

# %% [markdown]
# ### 2.3. Pour étudier la **relation entre deux variables**

# %% [markdown]
# **Nuage de points (scatter plot)** : pour analyser la relation entre deux variables, par exemple avant de réaliser une régression.

# %%
# Définition des coordonnées en abscisses (x)
x = [1, 2, 3, 4, 5]

# Définition des coordonnées en ordonnées (y) associées à chaque point x
y = [2.2, 2.8, 4.5, 3.7, 5.0]

# Création d'un nuage de points (scatter plot) pour visualiser la relation entre x et y
plt.scatter(x, y)

# Titre du graphique
plt.title("Corrélation X vs Y")

# Affichage du graphique
plt.show()

# %% [markdown]
# # 3. 📈📉 Comparer plusieurs graphiques dans une même figure

# %% [markdown]
# Lorsque vous analysez un dataset complexe, vous devez souvent explorer plusieurs dimensions en parallèle.
# Pouvoir afficher plusieurs visualisations sur une seule **figure** facilite la comparaison visuelle et cela grâce à la méthode `subplot`.

# %%
# Crée une figure avec une taille personnalisée (largeur = 10, hauteur = 8 pouces)
plt.figure(figsize=(10,8))

# Premier graphique (en haut à gauche) : diagramme en barres
plt.subplot(2,2,1)                                  # 2 lignes, 2 colonnes, 1er sous-graphe
plt.bar(mois, ventes)                               # Affiche les ventes par mois sous forme de barres
plt.title("Barres")                                 # Titre du graphique

# Deuxième graphique (en haut à droite) : nuage de points (scatter plot)
plt.subplot(2,2,2)                                  # 2 lignes, 2 colonnes, 2e sous-graphe
plt.scatter(x, y)                                   # Affiche la relation entre deux variables
plt.title("Scatter")                                # Titre du graphique

# Troisième graphique (en bas à gauche) : histogramme
plt.subplot(2,2,3)                                  # 2 lignes, 2 colonnes, 3e sous-graphe
plt.hist(notes, bins=5, rwidth=0.8)                 # Montre la distribution des notes
plt.title("Histogramme")                            # Titre du graphique

# Quatrième graphique (en bas à droite) : diagramme circulaire (camembert)
plt.subplot(2,2,4)                                  # 2 lignes, 2 colonnes, 4e sous-graphe
plt.pie(parts, labels=labels, autopct='%1.1f%%')    # Répartition des parts avec pourcentages
plt.title("Camembert")                              # Titre du graphique

# Ajuste automatiquement les espacements entre les sous-graphes pour éviter les chevauchements
plt.tight_layout()

# Affiche l’ensemble des graphiques
plt.show()

# %% [markdown]
# # 4. 🧩 Travailler avec un dataset réel

# %% [markdown]
# Dans cette section, vous allez manipuler un dataset réel en utilisant la bibliothèque pandas. Pour cela, vous allez utiliser le célèbre jeu de données [Iris](https://fr.wikipedia.org/wiki/Iris_de_Fisher), très utilisé en apprentissage automatique pour illustrer des tâches de classification.
#
# Le dataset contient des mesures de fleurs d’iris appartenant à trois espèces différentes :
# - Longueur et largeur des **sépales**
# - Longueur et largeur des **pétales**
# - Espèce de la fleur (**setosa**, **versicolor**, **virginica**)

# %% [markdown]
# > Chargez le jeu de données directement depuis l’URL suivante https://raw.githubusercontent.com/mwaskom/seaborn-data/master/iris.csv
# >
# > Affichez un histogramme de la longueur des sépales pour visualiser la distribution de cette variable continue.
# >
# > Utilisez un diagramme en barres pour afficher la répartition des espèces.
# >
# > Utilisez un nuage de points pour étudier la relation entre la longueur du sépale et celle du pétale

# %%
import pandas as pd
url = "https://raw.githubusercontent.com/mwaskom/seaborn-data/master/iris.csv"
df = pd.read_csv(url)

plt.figure(figsize=(10,8))

plt.subplot(2,2,1)
plt.hist(df["sepal_length"], bins=5, rwidth=0.8)
plt.title("Distribution de la longueur des sépales")
plt.xlabel("Longueur des sépales")
plt.ylabel("Fréquence")

species_counts = df["species"].value_counts()

plt.subplot(2,2,2)
plt.bar(species_counts.index, species_counts.values)
plt.title("Distribution des espèces")
plt.xlabel("Espèce")
plt.ylabel("Fréquence")

plt.subplot(2,2,3)
plt.scatter(df["sepal_length"], df["petal_length"])
plt.title("Corrélation longueur des sépales/longueur des pétales")
plt.xlabel("Longueur des sépales")
plt.ylabel("Longueur des pétales")

plt.tight_layout()

plt.show()

df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
