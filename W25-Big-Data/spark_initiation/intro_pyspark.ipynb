# %% [markdown]
# ![SPARK_PYSPARK](img/spark_pyspark.jpeg)

# %% [markdown]
# # 💫 Apache Spark : le moteur du Big Data moderne

# %% [markdown]
# Le **Big Data** désigne des volumes de données trop grands pour être traités sur une seule machine.
# Historiquement, on utilisait **Hadoop MapReduce**, mais celui-ci lisait et écrivait souvent sur disque → lent.
#
# **Apache Spark** est né pour répondre à ce problème.
# - **Traitement en mémoire (RAM)** → bien plus rapide
# - **API haut niveau** (SQL, DataFrame, MLlib, etc.)
# - **Multi-langages** : Scala, Java, Python (PySpark), R
#
# Spark repose sur une architecture driver / executors.
# - **Driver** : programme principal. Gère le plan d’exécution et collecte les résultats
# - **Cluster Manager** : alloue les ressources (CPU, RAM) aux tâches Spark (YARN, Kubernetes, Standalone…)
# - **Executors** : exécutent les tâches sur les partitions de données.
#
# Spark distribue automatiquement les données et le calcul sur plusieurs machines.

# %% [markdown]
# # ✨ PySpark : l’interface Python de Spark

# %% [markdown]
# **PySpark** est l’interface de programmation en Python pour Apache Spark.\
# Elle permet d’utiliser la puissance du moteur Spark tout en restant dans un environnement familier pour les développeurs Python.
#
# Concrètement :
# - Le code écrit en Python est traduit en instructions que le moteur Spark exécute sur le cluster.
# - L’exécution réelle ne se fait pas dans le processus Python, mais dans la JVM de Spark (Java Virtual Machine).
# - Cette communication passe par l’API Py4J, une passerelle entre Python et Java.
#
# Ainsi, PySpark combine :
# - la simplicité du Python (syntaxe, intégration avec pandas, notebooks, etc.)
# - la scalabilité de Spark, capable de traiter des téraoctets de données sur des centaines de noeuds.

# %% [markdown]
# # ⌨️ Hands-On

# %% [markdown]
# **Objectifs**
# - Comprendre comment démarrer une `SparkSession` en local
# - Manipuler des DataFrames PySpark (lecture, inspection, transformations)
# - Comprendre `lazy evaluation`, `action`, `job / stage / task`
# - Sauvegarder/relire des données (CSV, Parquet)

# %% [markdown]
# ## 1. Démarrer Spark en local

# %% [markdown]
# Avant de pouvoir manipuler des données avec PySpark, il faut créer une session Spark.\
# Cette session est le point d’entrée principal vers toutes les fonctionnalités de Spark (lecture de données, SQL, transformations, machine learning, etc.).
#
# En pratique, on la crée à l’aide de la classe **SparkSession** qui permet de configurer et d’initialiser le moteur Spark.\
# Une fois cette cellule exécutée, Spark démarre un contexte local et affiche des informations dans la console.
# C’est le signe que le driver est prêt à exécuter des tâches et à communiquer avec d’éventuels executors.

# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder \
    .appName("IntroSparkLocal") \
    .master("local[*]") \
    .getOrCreate()

# SparkSession.builder crée un objet constructeur pour définir les paramètres de la session.
# .appName("IntroSparkLocal") définit un nom d’application visible dans l’interface Spark (utile pour identifier ton job).
# .master("local[*]") indique le mode d’exécution :
#       - local signifie que le calcul se fera sur la machine locale.
#       - [*] indique que Spark utilisera tous les cœurs CPU disponibles.
# .getOrCreate() crée une nouvelle session Spark si elle n’existe pas encore, ou récupère celle déjà active.
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# 25/10/16 11:30:09 WARN Utils: Your hostname, charles-petit-Aspire-A317-54, resolves to a loopback address: 127.0.1.1; using 10.27.0.69 instead (on interface enp42s0)
# 25/10/16 11:30:09 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 25/10/16 11:30:10 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %% [markdown]
# Aussi, Spark démarre une interface web accessible à l’adresse suivante : http://localhost:4040
#
# Cette interface permet de :
# - visualiser les jobs Spark en cours ou terminés
# - consulter les stages et tasks
# - analyser les plans d’exécution
# - suivre l’utilisation des ressources locales (mémoire, CPU)
#
# ### 🧭 Exploration recommandée
#
# Ouvrir l’URL http://localhost:4040 dans le navigateur.
# Parcourir les différentes sections pour comprendre comment Spark gère un traitement distribué :
# - Jobs : résumé des traitements lancés,
# - Stages : décomposition logique des jobs,
# - Tasks : exécution concrète sur les partitions de données,
# - Storage : aperçu du cache et des données en mémoire.
#
# Prendre quelques minutes pour parcourir cette interface avant de continuer car elle aidera à visualiser ce qui se passe “sous le capot” à chaque fois qu'une opération est exécutée dans PySpark.

# %% [markdown]
# ## 2. Charger le dataset de test :  `employees.csv`

# %% [markdown]
# Pour travailler concrètement avec Spark, nous allons charger un petit dataset de test nommé `employees.csv`.\
# Ce fichier contient des informations simples sur des employés : identifiant, nom, âge, département, salaire et années d’expérience.
#
# Dans PySpark, la lecture d’un fichier CSV s’effectue via la méthode `spark.read.csv()`.
# Cette méthode renvoie un **DataFrame Spark,** c’est-à-dire une **structure tabulaire distribuée** (semblable à un tableau SQL ou à un DataFrame Pandas, mais répartie sur plusieurs noeuds).

# %%
# Charge le fichier csv
# header=True indique que la première ligne contient les noms des colonnes
# inferSchema=True demande à Spark de déduire automatiquement les types de données sinon toutes les colonnes seraient lues comme des chaînes de caractères
df = spark.read.csv("./data/employees.csv", header=True, inferSchema=True)

# Affiche la structure (schéma) du DataFrame, c’est-à-dire les noms de colonnes et leurs types 
df.printSchema()
# Out:
# root
#  |-- employee_id: integer (nullable = true)
#  |-- name: string (nullable = true)
#  |-- age: double (nullable = true)
#  |-- department: string (nullable = true)
#  |-- salary: double (nullable = true)
#  |-- experience_years: integer (nullable = true)

# %% [markdown]
# 🔍 **Détaillons ce qu’il se passe en arrière-plan.**
#
# Lors de la lecture du CSV :
# 1. Le driver Spark reçoit la requête de lecture du fichier csv. Il construit un plan logique pour lire le fichier CSV. Le plan logique est une représentation interne (sous forme d’un graphe `DAG`) qui décrit les étapes nécessaires pour obtenir le résultat final : *"quel fichier lire"*, *"avec quel format (ici CSV)"*, *"quelles colonnes ou types de données"*, *"quelles transformations appliquer (filtres, jointures, agrégations, etc.)"*\
# Mais à ce stade, **rien n’est encore exécuté**. Spark se contente de noter l’**intention du programme**.
# 2. Quand une action est déclenchée (.show(), .count(), etc.), le driver envoie les tâches aux executors.
# 3. Les executors lisent réellement les données (leurs partitions), exécutent les transformations, et renvoient leurs résultats partiels au driver. (En mode local, les executors sont simplement des threads dans le même processus JVM que le driver.)
# 4. Le driver agrège ces résultats et les renvoie au programme Python.
#
# Même pour un petit CSV local, le mécanisme est le même que sur un cluster : Spark applique toujours un modèle distribué. Cela rend le passage à grande échelle quasiment transparent pour le code.

# %% [markdown]
# ### 2.1. Inspection de base

# %% [markdown]
# Avant de transformer les données, il est souvent utile de vérifier la structure du DataFrame.\
# L'opération est immédiate : elle interroge seulement les métadonnées du DataFrame (pas les données elles-mêmes).

# %%
df.columns
# Out:
# ['employee_id', 'name', 'age', 'department', 'salary', 'experience_years']

# %% [markdown]
# ### 2.2. Lazy Evaluation

# %% [markdown]
# ⚠️ Contrairement à df.columns, les instructions suivantes déclenchent des actions Spark.\
# Le moteur Spark exécute réellement des jobs distribués pour lire les données, parcourir toutes les partitions et agréger les résultats partiels.
#
# 🔍 **Détaillons ce qu’il se passe en arrière-plan.**
# - `df.count()` parcourt l’ensemble du DataFrame pour compter le nombre de lignes. Pour cela : \
# Spark crée un job composé de plusieurs stages et tasks, chacun exécuté par les executors sur une partition de données.\
# Une fois terminées, les executors envoient leurs résultats partiels (leurs counts locaux) au driver.\
# Le driver additionne ces valeurs pour obtenir le compte global du DataFrame,
# puis renvoie le résultat final au programme Python.
# - `df.show(5)` demande à Spark d’afficher les 5 premières lignes du DataFrame.
# Cela nécessite de lire physiquement les données (au moins partiellement) → Spark déclenche donc aussi un job distribué.

# %%
display(df.count())
display(df.show(5))
# Out:
# 10000
# +-----------+---------------+----+----------+-------+----------------+
# |employee_id|           name| age|department| salary|experience_years|
# +-----------+---------------+----+----------+-------+----------------+
# |          1|      Ugo Petit|36.0|        IT|6364.39|              10|
# |          2|  Claire Girard|21.0|       r&d|   NULL|               3|
# |          3|Wassim Lefebvre|45.0|   support|   NULL|              13|
# |          4|Wassim Bertrand|36.0|Operations|6504.21|              14|
# |          5|    Liam Garcia|21.0|     Sales|3631.12|               3|
# +-----------+---------------+----+----------+-------+----------------+
# only showing top 5 rows
# None

# %% [markdown]
# ## 3. Sélections, filtres, tris

# %% [markdown]
# Dans Spark, les DataFrames offrent une interface haut niveau pour manipuler les données de manière déclarative, un peu comme en SQL.
# Les opérations de sélection, filtrage et tri sont des transformations qui **ne modifient pas les données originales** : elles produisent de **nouveaux DataFrames**.
#
# 💡 Chaque transformation crée un nouveau plan logique dans Spark (**aucune lecture ou exécution réelle n’a lieu** tant qu’une action, comme .show() ou .count(), n’est pas appelée).\
# Ainsi, même un simple tri ou filtre suit la même logique de planification distribuée que sur un cluster.

# %%
from pyspark.sql.functions import col

# Sélection de colonnes
df_sel = df.select("name", "age", "department")
df_sel.show(5)

# Filtres
employees_filtered = df_sel.filter(col("age") >= 30) # Ne conserver que les employés d'un certain âge
employees_filtered = employees_filtered.orderBy(col("age").desc())
employees_filtered.show(5)
# Out:
# +---------------+----+----------+
# |           name| age|department|
# +---------------+----+----------+
# |      Ugo Petit|36.0|        IT|
# |  Claire Girard|21.0|       r&d|
# |Wassim Lefebvre|45.0|   support|
# |Wassim Bertrand|36.0|Operations|
# |    Liam Garcia|21.0|     Sales|
# +---------------+----+----------+
# only showing top 5 rows
# +---------------+----+----------+
# |           name| age|department|
# +---------------+----+----------+
# |  Giulia Girard|64.0|operations|
# |Wassim Lefebvre|64.0|   Finance|
# |   Farid Durand|64.0| Support  |
# | Alice Lefebvre|64.0| Marketing|
# |    Ziad Martin|64.0|       R&D|
# +---------------+----+----------+
# only showing top 5 rows

# %% [markdown]
# ### 3.1. Spark SQL

# %% [markdown]
# Il est possible d’écrire directement du ***SQL*** grâce à ***Spark SQL***, un module intégré à Apache Spark qui permet d’interroger les données via des requêtes SQL standard.\
# Pour cela, il suffit d’enregistrer un DataFrame comme vue temporaire à l’aide de `createOrReplaceTempView()`. Cette vue agit comme une table virtuelle accessible uniquement durant la session en cours.\
# On peut ensuite exécuter des requêtes SQL sur cette vue avec la méthode `spark.sql()`, comme dans l’exemple ci-dessous, qui fait exactement la même chose que le job précédent.

# %%
# Création ou remplacement d'une vue temporaire à partir du DataFrame
df.createOrReplaceTempView("employees")

# Requête SQL exécutée via Spark SQL
result = spark.sql("""
    SELECT department,
           AVG(salary) AS avg_salary
    FROM employees
    GROUP BY department
""")

# Affichage du résultat
result.show()
# Out:
# +------------+------------------+
# |  department|        avg_salary|
# +------------+------------------+
# |     Legal  | 7160.863068181826|
# |         r&d| 6943.013473684209|
# |       Sales| 5572.902567567568|
# |Operations  |  5422.08880794702|
# |     finance|6706.1631499999985|
# |       legal| 7365.044111675121|
# |       Legal| 7523.037461928936|
# |   MARKETING| 5363.743197674419|
# |          HR| 4828.136005509641|
# |     Sales  | 5597.308164556963|
# |     Support| 4397.905555555553|
# |  OPERATIONS| 5444.523483146067|
# |     Finance|  6891.88554216867|
# |       SALES| 5713.909941860465|
# |       R&D  | 6886.110502793296|
# |          Hr|  4954.37892655367|
# |   marketing| 5268.799746192894|
# |        HR  | 4892.545178571427|
# |       sales| 5668.184748603351|
# |         R&D| 6728.667552083339|
# +------------+------------------+
# only showing top 20 rows

# %% [markdown]
# ### 🧩 Exercices

# %% [markdown]
# > Essayez de modifier et d’expérimenter :
# > - sélectionnez d’autres colonnes avec .select().
# > - changez la condition du filtre (age < 25, department == "HR", etc.).
# > - triez par une autre colonne, ou combinez plusieurs tris
# > - ajoutez plusieurs conditions avec les opérateurs logiques `&` (et), `|` (ou)

# %%
# Requête SQL exécutée via Spark SQL
result = spark.sql("""
    SELECT name, age, salary
    FROM employees
    WHERE age < 25
""")

# Affichage du résultat
result.show()
# Out:
# +-------------+----+-------+
# |         name| age| salary|
# +-------------+----+-------+
# |Claire Girard|21.0|   NULL|
# |  Liam Garcia|21.0|3631.12|
# |   Ziad Simon|22.0|4627.71|
# |  Bob Mercier|22.0|4016.88|
# | David Durand|19.0|2987.36|
# | Pablo Dubois|22.0|5176.94|
# |   Alice Roux|23.0|3636.55|
# |   Qi Vincent|22.0|   NULL|
# |  Maya Michel|23.0|4349.87|
# |Giulia Garcia|23.0| 5186.7|
# |Wassim Robert|23.0|4377.09|
# | Sara Mercier|24.0| 4973.4|
# | Ines Bernard|20.0|4921.88|
# | Rita Vincent|24.0|4396.25|
# |    Val David|21.0|3433.01|
# |Emma Bertrand|23.0| 4450.8|
# |  Sara Garcia|24.0|5536.49|
# |Rita Lefebvre|22.0|4296.24|
# |  Ziad Girard|23.0|4065.62|
# |David Vincent|23.0|5643.53|
# +-------------+----+-------+
# only showing top 20 rows

# %% [markdown]
# > Pensez à tester aussi Spark SQL dans cet exercice.

# %%
employees_filtered = df_sel.filter(col("age") >= 15) # Ne conserver que les employés d'un certain âge
employees_filtered = employees_filtered.orderBy(col("age").asc())
employees_filtered.show(5)
# Out:
# +------------+----+----------+
# |        name| age|department|
# +------------+----+----------+
# | Maya Girard|19.0|      HR  |
# | Ugo Vincent|19.0|     Legal|
# |  Emma Morel|19.0|        it|
# |David Robert|19.0|     SALES|
# | David Petit|19.0| Marketing|
# +------------+----+----------+
# only showing top 5 rows

# %% [markdown]
# ## 4. Nettoyage des données

# %% [markdown]
# Dans Spark, nous pouvons appliquer des fonctions de transformation directement sur les colonnes d’un DataFrame de manière distribuée.
#
# Dans l’exemple ci-dessous :
# - nous normalisons les noms de département
# - nous traitons les valeurs manquantes
#
# 💡 Ces opérations sont aussi "lazy" : elles ne modifient pas les données tant qu’aucune action n’est exécutée.

# %%
from pyspark.sql.functions import when, trim, upper

# Normaliser le nom du département: trim + upper
df_sel = df
df_clean = df_sel.withColumn("department_norm", upper(trim(col("department"))))

# Gérer les valeurs manquantes d'âge et de salaire
df_clean = df_clean.withColumn("age", when(col("age").isNull(), 0).otherwise(col("age")))
df_clean = df_clean.na.fill({"salary": 0.0})

df_clean.select("employee_id","name","department","department_norm","age","salary").show(5)
# Out:
# +-----------+---------------+----------+---------------+----+-------+
# |employee_id|           name|department|department_norm| age| salary|
# +-----------+---------------+----------+---------------+----+-------+
# |          1|      Ugo Petit|        IT|             IT|36.0|6364.39|
# |          2|  Claire Girard|       r&d|            R&D|21.0|    0.0|
# |          3|Wassim Lefebvre|   support|        SUPPORT|45.0|    0.0|
# |          4|Wassim Bertrand|Operations|     OPERATIONS|36.0|6504.21|
# |          5|    Liam Garcia|     Sales|          SALES|21.0|3631.12|
# +-----------+---------------+----------+---------------+----+-------+
# only showing top 5 rows

# %% [markdown]
# ### 4.1. Créer des colonnes calculées

# %% [markdown]
# La préparation des données consiste aussi à créer de nouvelles colonnes dérivées à partir des colonnes existantes.\
# Dans Spark, cela se fait avec la méthode `withColumn()`, qui permet d’ajouter une colonne calculée sans modifier le DataFrame original.
#
# 👉 Si le nom de colonne existe déjà, la colonne est remplacée (écrasée) par la nouvelle version.\
# 👉 Si le nom n’existe pas, une nouvelle colonne est simplement ajoutée au DataFrame, c'est le cas dans l'exemple suivant.

# %%
from pyspark.sql.functions import avg

# Catégoriser les revenus
df_feat = df_clean.withColumn(
    "salary_band",
    when(col("salary") < 3000, "LOW").when(col("salary") < 6000, "MID").otherwise("HIGH")
)

df_feat.show(5)
# Out:
# +-----------+---------------+----+----------+-------+----------------+---------------+-----------+
# |employee_id|           name| age|department| salary|experience_years|department_norm|salary_band|
# +-----------+---------------+----+----------+-------+----------------+---------------+-----------+
# |          1|      Ugo Petit|36.0|        IT|6364.39|              10|             IT|       HIGH|
# |          2|  Claire Girard|21.0|       r&d|    0.0|               3|            R&D|        LOW|
# |          3|Wassim Lefebvre|45.0|   support|    0.0|              13|        SUPPORT|        LOW|
# |          4|Wassim Bertrand|36.0|Operations|6504.21|              14|     OPERATIONS|       HIGH|
# |          5|    Liam Garcia|21.0|     Sales|3631.12|               3|          SALES|        MID|
# +-----------+---------------+----+----------+-------+----------------+---------------+-----------+
# only showing top 5 rows

# %% [markdown]
# ## 5. Regroupement et agrégation

# %% [markdown]
# La phase d’agrégation permet de résumer, regrouper et interpréter les informations issues de grands volumes de données.\
# Avec PySpark, ces opérations s’effectuent facilement grâce aux fonctions de groupement (`groupBy`), de comptage (`count`), et d’agrégation (`agg`).

# %%
# Nombre d'employés par catégorie de revenus
df_feat\
    .groupBy("salary_band")\
    .count()\
    .orderBy(col("count").desc())\
    .show()
# Out:
# +-----------+-----+
# |salary_band|count|
# +-----------+-----+
# |        MID| 5476|
# |       HIGH| 4175|
# |        LOW|  349|
# +-----------+-----+

# %%
from pyspark.sql.functions import round as sround

# Analyse des salaires moyens par département 
dept_stats = df_feat\
                .groupBy("department_norm")\
                .agg(sround(avg("salary"),2).alias("avg_salary"))\
                .orderBy(col("avg_salary").desc())

dept_stats.show()
# Out:
# +---------------+----------+
# |department_norm|avg_salary|
# +---------------+----------+
# |          LEGAL|   7098.72|
# |            R&D|    6621.4|
# |        FINANCE|   6598.94|
# |             IT|   6207.31|
# |          SALES|   5437.99|
# |     OPERATIONS|   5227.45|
# |      MARKETING|   5185.57|
# |             HR|   4690.68|
# |        SUPPORT|    4177.1|
# +---------------+----------+

# %% [markdown]
# ### 🧩 Exercices

# %% [markdown]
# > Comment Spark découpe les transformations ci-dessus en **stages** ?
# > Ouvrez l'onglet **SQL / DAG** dans l'UI Spark puis analysez les informations présentées.

# %% [markdown]
# ## 6. Sauvegarde de résultats (CSV / Parquet)

# %% [markdown]
# Une fois les traitements réalisés nous pouvons sauvegarder les résultats pour les réutiliser ou les partager.\
# PySpark permet d’écrire facilement un DataFrame dans différents formats, notamment CSV et Parquet (format binaire optimisé pour le Big Data).
#
# - Le format CSV est universel mais peu efficace sur de gros volumes, car il ne conserve pas les types de données.
# - Le format Parquet, lui, conserve le schéma, compresse les données et accélère les lectures : il est donc privilégié dans les environnements distribués.
#
# ### 🔎 Format Parquet
# Pour aller plus loin concernant le format Parquet, voici quelques ressources :
# - 📘 [Documentation officielle Apache Parquet](https://parquet.apache.org/docs/)
# - 🎥 [Qu’est-ce qu'une base de données orientée colonne ?](https://www.youtube.com/watch?v=1MnvuNg33pA)

# %%
# Écriture en CSV (dossier de sortie partitionné)
dept_stats.write.mode("overwrite").csv("./outputs/dept_stats_csv")

# Écriture en Parquet (conserve le schéma, plus efficace)
dept_stats.write.mode("overwrite").parquet("./outputs/dept_stats_parquet")

# Relecture du Parquet
reloaded = spark.read.parquet("./outputs/dept_stats_parquet")
reloaded.printSchema()
reloaded.show()
# Out:
# root
#  |-- department_norm: string (nullable = true)
#  |-- avg_salary: double (nullable = true)
#
# +---------------+----------+
# |department_norm|avg_salary|
# +---------------+----------+
# |          LEGAL|   7098.72|
# |            R&D|    6621.4|
# |        FINANCE|   6598.94|
# |             IT|   6207.31|
# |          SALES|   5437.99|
# |     OPERATIONS|   5227.45|
# |      MARKETING|   5185.57|
# |             HR|   4690.68|
# |        SUPPORT|    4177.1|
# +---------------+----------+

# %% [markdown]
# ## 7. RDD (Resilient Distributed Dataset)

# %% [markdown]
# Jusqu’à présent, vous avez manipulé des **DataFrames** : une interface structurée, avec des colonnes nommées, des types de données, et des opérations familières (sélection, groupBy, agg, etc.).\
# Les DataFrames sont très pratiques, car ils permettent d’écrire du code lisible et optimisé grâce au moteur **Catalyst** de Spark.
#
# Mais sous cette interface haut niveau se cache la brique fondamentale de Spark : le **RDD (Resilient Distributed Dataset)**.\
# Comprendre ce concept vous permettra de mieux saisir comment Spark distribue, exécute et reconstruit vos données à grande échelle.
#
# Un RDD est une collection d’objets distribuée à travers le cluster Spark.
# - **Resilient** : il peut être reconstruit automatiquement en cas de panne.
# - **Distributed** : les données sont découpées en partitions réparties sur plusieurs nœuds.
# - **Dataset** : c’est simplement un ensemble d’éléments (lignes, objets, etc.).
#
# Autrement dit, un RDD est une collection répartie sur plusieurs machines, que Spark sait manipuler en parallèle.

# %% [markdown]
# ### 7.1. Manipulation de base

# %%
sc = spark.sparkContext

# Exemple d'un RDD à partir d’une liste locale
# Spark crée un RDD contenant ces 5 éléments.
rdd = sc.parallelize([1, 2, 3, 4, 5])

# %%
# Rien n’est exécuté tant qu’on ne déclenche pas une action
display(rdd.collect())
# Out:
# [1, 2, 3, 4, 5]

# %%
# On peut transformer les données
rdd2 = rdd.map(lambda x: x * 2)
display(rdd2.collect())
# Out:
# [2, 4, 6, 8, 10]

# %% [markdown]
# #### 🧩 Exercices

# %% [markdown]
# > Soit la liste de produits :
#
# ```bash
# ventes = [
#     ("chaise", 200),
#     ("table", 450),
#     ("lampe", 100),
#     ("chaise", 150),
#     ("table", 300),
#     ("lampe", 80)
# ]
# ```
#
# > - Créez un RDD à partir de cette liste.
# > - Récupérez les produits dont le prix dépasse 100€
# > - Calculez le CA total par produit (possible d'utiliser .reduceByKey())
# > - Triez par CA décroissant (possible d'utiliser .sortBy())

# %%
from operator import add

ventes = [
    ("chaise", 200),
    ("table", 450),
    ("lampe", 100),
    ("chaise", 150),
    ("table", 300),
    ("lampe", 80)
]

sc = spark.sparkContext

rdd = sc.parallelize(ventes)

rdd = rdd.filter(lambda x: x[1] > 100)
rdd = rdd.reduceByKey(add)
rdd = rdd.sortBy(lambda x: x[1], False)

display(rdd.collect())
# Out:
# [('table', 750), ('chaise', 350)]

# %% [markdown]
# ### 7.2. Manipulation de fichiers

# %%
# Spark permet de lire et de manipuler des fichiers sous forme de RDD.
employees_rdd = sc.textFile("./data/employees.csv")
employees_rdd.collect()
# Out:
# ['employee_id,name,age,department,salary,experience_years',
#  '1,Ugo Petit,36.0, IT,6364.39,10',
#  '2,Claire Girard,21.0,r&d,,3',
#  '3,Wassim Lefebvre,45.0,support,,13',
#  '4,Wassim Bertrand,36.0,Operations,6504.21,14',
#  '5,Liam Garcia,21.0, Sales,3631.12,3',
#  '6,Jamal Lefebvre,55.0,Operations,6326.51,16',
#  '7,Hugo Petit,36.0,R&D  ,5324.09,4',
#  '8,Ines Mercier,57.0,HR,4841.89,13',
#  '9,Ugo Morel,62.0,MARKETING,6458.18,15',
#  '10,Maya Laurent,32.0,Hr,4778.46,12',
#  '11,Maya Lefebvre,28.0, Legal,6544.79,7',
#  '12,Noah Girard,42.0,R&D,8340.55,13',
#  '13,David Robert,62.0, Finance,8031.07,16',
#  '14,Ines Morel,62.0,IT  ,7073.72,16',
#  '15,Katia Petit,46.0, Sales,6020.27,13',
#  '16,Yara Richard,25.0,support,3656.43,7',
#  '17,Liam Richard,52.0,SUPPORT,4961.28,18',
#  '18,Ziad Simon,22.0,Marketing,4627.71,4',
#  '19,Yara Morel,27.0, Finance,4376.96,3',
#  '20,Noah Dubois,63.0,Support,5407.19,18',
#  '21,Qi Roux,34.0,hr,4969.09,10',
#  '22,Alice Bernard,33.0,IT,6231.15,10',
#  '23,Val Vincent,53.0,Marketing,7158.99,19',
#  '24,Ziad Bertrand,25.0,Marketing  ,4902.27,7',
#  '25,Bob Mercier,22.0,hr,4016.88,4',
#  '26,Rita Roux,46.0, Finance,7825.58,14',
#  '27,David Durand,19.0,Support,2987.36,1',
#  '28,Pablo Dubois,22.0,R&d,5176.94,4',
#  '29,Jamal Bertrand,61.0, Support,4869.43,17',
#  '30,Xia Morel,39.0,it,7219.7,14',
#  '31,Bob Fournier,30.0, HR,4606.98,9',
#  '32,Hugo Girard,58.0,IT,8616.31,20',
#  '33,Giulia Mercier,34.0,Operations,5188.14,9',
#  '34,Alice Roux,23.0,HR,3636.55,3',
#  '35,Hugo Garcia,29.0,Sales  ,4342.22,4',
#  '36,Qi Martin,38.0,Support,4381.67,12',
#  '37,Xia Morel,36.0,FINANCE,6572.24,9',
#  '38,Qi Vincent,22.0,sales,,4',
#  '39,Ugo Laurent,,Finance  ,6498.88,10',
#  '40,Emma Morel,42.0,IT,6115.84,10',
#  '41,Liam Dubois,61.0, Marketing,7274.28,21',
#  '42,Xia Robert,29.0,Marketing  ,,11',
#  '43,Katia Bertrand,36.0,Marketing,5912.49,12',
#  '44,Hugo Dubois,41.0,legal,,9',
#  '45,Maya Michel,23.0, Sales,4349.87,5',
#  '46,Katia Martin,35.0,Hr,5812.73,13',
#  '47,Liam Michel,57.0,R&D,8265.29,17',
#  '48,Wassim Bertrand,52.0,IT  ,7791.84,18',
#  '49,Giulia Garcia,23.0,R&D,5186.7,5',
#  '50,Xia Simon,38.0,support,3848.95,9',
#  '51,Noah Mercier,62.0,R&D,8094.5,17',
#  '52,Jamal Simon,46.0,Marketing  ,5440.48,14',
#  '53,Giulia Fournier,29.0,Legal,5854.0,6',
#  '54,Yara Moreau,33.0, Sales,5241.19,10',
#  '55,Yara Bernard,45.0,Legal,8142.34,15',
#  '56,Hugo Robert,25.0,It,5332.51,7',
#  '57,Bob Morel,26.0, Marketing,4065.73,2',
#  '58,Katia Roux,46.0,Support,4349.41,14',
#  '59,Omar Laurent,59.0,Marketing,6512.6,15',
#  '60,Claire Simon,36.0,Marketing,5264.24,7',
#  '61,Wassim Robert,23.0,Marketing,4377.09,4',
#  '62,Maya Girard,55.0,It,7322.28,15',
#  '63,Rita Morel,,Marketing  ,6155.08,14',
#  '64,Ziad David,48.0, Finance,8721.72,21',
#  '65,Sara Mercier,24.0,It,4973.4,5',
#  '66,Katia Dubois,39.0,Legal,6846.37,7',
#  '67,Ines Bernard,20.0,Legal,4921.88,2',
#  '68,Yara Lefebvre,,it,4377.72,2',
#  '69,Pablo Mercier,55.0, HR,5711.82,18',
#  '70,Tom Petit,38.0,Finance,6872.99,11',
#  '71,Maya Dubois,56.0,HR  ,4867.54,14',
#  '72,Tom Petit,41.0,IT,5449.79,7',
#  '73,Noah Vincent,46.0,Hr,5576.04,17',
#  '74,Farid Fournier,58.0,Sales  ,6451.75,17',
#  '75,Sara Laurent,34.0,Operations,5088.35,10',
#  '76,Sara Andre,40.0,R&D,8384.98,17',
#  '77,Katia Laurent,54.0,Sales,7846.51,22',
#  '78,Rita Moreau,,Legal,8342.23,16',
#  '79,Wassim Moreau,61.0,Sales  ,6033.45,14',
#  '80,Rita Michel,63.0,OPERATIONS,6123.57,15',
#  '81,David Morel,31.0, Finance,6707.53,9',
#  '82,Tom Simon,31.0,hr,4691.97,8',
#  '83,Ines Durand,54.0,IT,7555.4,13',
#  '84,Alice Girard,49.0,Sales,5636.51,11',
#  '85,David Bernard,50.0, R&D,8709.74,18',
#  '86,Jamal Bernard,26.0, Marketing,4128.94,4',
#  '87,Maya Roux,38.0, Legal,7958.85,16',
#  '88,Xia Petit,59.0,Marketing,6747.77,17',
#  '89,Farid Martin,47.0,R&D,6766.22,12',
#  '90,Wassim Roux,62.0,hr,5913.91,17',
#  '91,Noah Petit,33.0,support,3075.11,5',
#  '92,Ziad Simon,47.0, Sales,6922.75,16',
#  '93,Rita Vincent,24.0,Legal,4396.25,1',
#  '94,Claire Moreau,62.0, IT,7825.8,19',
#  '95,Ugo Roux,30.0,Sales,5593.84,11',
#  '96,Liam Bertrand,39.0,OPERATIONS,4340.58,8',
#  '97,Val David,21.0,Support,3433.01,3',
#  '98,Qi Martin,48.0,Support  ,4540.26,12',
#  '99,Omar Durand,36.0,Marketing,3870.73,3',
#  '100,Alice Lefebvre,64.0,Marketing,7118.39,20',
#  '101,Omar Petit,50.0,Finance,7877.65,16',
#  '102,Pablo Moreau,54.0,legal,8813.89,16',
#  '103,Claire Laurent,40.0,R&D,7416.6,14',
#  '104,Sara Girard,28.0,Legal,5653.79,4',
#  '105,Omar Michel,63.0,MARKETING,6774.08,18',
#  '106,Xia Vincent,43.0,R&D,8241.31,17',
#  '107,Emma Fournier,25.0,Operations  ,4460.3,7',
#  '108,Emma Bertrand,23.0,Finance  ,4450.8,0',
#  '109,Claire Michel,43.0, Support,4800.3,16',
#  '110,Bob Andre,34.0,Hr,3503.99,5',
#  '111,David Lefebvre,,HR,5478.96,14',
#  '112,Jamal Garcia,46.0,operations,6342.58,15',
#  '113,Farid Bernard,58.0,R&D  ,7478.58,15',
#  '114,Ines Roux,61.0,sales,7831.99,22',
#  '115,Claire Roux,56.0,OPERATIONS,6441.01,13',
#  '116,Giulia David,25.0,LEGAL,6709.53,7',
#  '117,Alice Mercier,36.0, R&D,8070.54,16',
#  '118,Xia Vincent,33.0,Sales  ,4625.77,7',
#  '119,Yara Mercier,59.0,Finance,9141.68,20',
#  '120,Sara Garcia,24.0, Finance,5536.49,6',
#  '121,Liam Fournier,36.0,SUPPORT,4117.71,11',
#  '122,Xia Michel,48.0,HR  ,5361.82,15',
#  '123,Val David,42.0,SUPPORT,4841.52,14',
#  '124,Val Mercier,56.0,Sales,6090.96,12',
#  '125,Alice Andre,39.0,Support  ,4332.26,12',
#  '126,Jamal Lefebvre,26.0,R&D,6678.31,8',
#  '127,Hugo Morel,43.0,Finance,6268.37,8',
#  '128,Sara Robert,60.0,R&D,8962.7,19',
#  '129,Wassim Garcia,47.0,MARKETING,5434.98,11',
#  '130,Rita Lefebvre,22.0,Operations,4296.24,4',
#  '131,Claire Mercier,60.0,marketing,4906.24,12',
#  '132,Ziad Girard,23.0,marketing,4065.62,5',
#  '133,Katia Robert,36.0,it,6289.7,11',
#  '134,David Mercier,27.0,it,6029.41,9',
#  '135,Ines Durand,45.0, Finance,5829.0,7',
#  '136,Sara Petit,51.0,Legal  ,8807.96,15',
#  '137,Qi Simon,60.0,Legal  ,9156.18,18',
#  '138,David Vincent,23.0, Legal,5643.53,5',
#  '139,Ugo Girard,64.0, Support,5423.7,13',
#  '140,Noah Petit,60.0,Hr,4842.8,14',
#  '141,Hugo Bertrand,48.0,OPERATIONS,5318.32,9',
#  '142,Liam Robert,23.0,LEGAL,5868.73,5',
#  '143,Ziad Robert,22.0,SUPPORT,3040.84,2',
#  '144,Val Bertrand,37.0,IT  ,5595.26,8',
#  '145,Pablo Moreau,41.0,Hr,4882.86,13',
#  '146,Rita Andre,20.0,SUPPORT,,2',
#  '147,Wassim Simon,41.0,operations,6413.24,17',
#  '148,Xia Lefebvre,24.0,IT,5111.25,6',
#  '149,Jamal Michel,22.0,Hr,4276.84,4',
#  '150,Val Bertrand,57.0,Legal,8225.35,14',
#  '151,David Simon,52.0,Legal,8060.65,14',
#  '152,Giulia Simon,27.0,Marketing,4472.97,7',
#  '153,Farid Robert,53.0,R&D,7221.51,14',
#  '154,Maya Durand,20.0,R&d,4710.22,2',
#  '155,Wassim Lefebvre,37.0, R&D,6880.78,11',
#  '156,Omar Garcia,46.0,Hr,5074.31,14',
#  '157,Jamal Michel,40.0,marketing,5242.41,11',
#  '158,Yara Garcia,60.0, Operations,6357.87,18',
#  '159,Emma Lefebvre,30.0, HR,4852.9,12',
#  '160,Omar Mercier,59.0,OPERATIONS,6345.46,15',
#  '161,Sara Durand,51.0,OPERATIONS,6540.08,17',
#  '162,Claire Lefebvre,58.0,HR  ,5095.29,14',
#  '163,Bob Roux,39.0,MARKETING,4663.07,8',
#  '164,Wassim Bernard,60.0, Support,5360.09,18',
#  '165,Tom Richard,42.0,Operations,5733.55,14',
#  '166,Ziad Lefebvre,23.0,Operations  ,4516.28,4',
#  '167,Tom Robert,24.0,Operations  ,4267.7,5',
#  '168,Val David,57.0,FINANCE,7627.97,15',
#  '169,Emma Mercier,24.0,support,3230.01,4',
#  '170,Giulia Michel,31.0,Legal,7001.45,9',
#  '171,Qi Morel,21.0,support,2718.1,2',
#  '172,Farid Richard,47.0, Finance,8057.41,16',
#  '173,Jamal Roux,53.0,marketing,6777.0,15',
#  '174,Liam Mercier,48.0,legal,7623.29,14',
#  '175,Giulia Andre,35.0,Finance  ,7400.57,13',
#  '176,Qi Petit,24.0,Sales,4361.36,6',
#  '177,Claire Moreau,41.0,Legal,8008.59,14',
#  '178,Claire Garcia,20.0,marketing,4044.48,2',
#  '179,Emma Durand,49.0,Sales,5845.33,13',
#  '180,Claire Martin,32.0,Sales,5274.17,11',
#  '181,Yara Simon,38.0,Marketing,5673.44,12',
#  '182,David Vincent,20.0,Support,2950.62,2',
#  '183,Tom Garcia,55.0,Marketing,5581.89,11',
#  '184,Qi Morel,51.0,SUPPORT,4220.38,11',
#  '185,Ines Martin,23.0,Operations  ,4413.54,3',
#  '186,Yara Michel,21.0,Finance  ,5208.33,3',
#  '187,Omar Vincent,27.0,Finance,6570.45,9',
#  '188,Ziad Dubois,39.0,IT,6933.21,14',
#  '189,Bob Lefebvre,37.0,Marketing,5129.02,7',
#  '190,Ziad Garcia,44.0,R&d,6444.12,12',
#  '191,Wassim Vincent,52.0,operations,6003.89,14',
#  '192,Rita Simon,25.0,Operations,4902.73,7',
#  '193,Farid Roux,47.0,OPERATIONS,6889.39,19',
#  '194,Ugo Durand,61.0,HR,5183.22,15',
#  '195,Emma Andre,21.0, Legal,5436.85,3',
#  '196,Bob Andre,62.0,finance,7609.4,14',
#  '197,Qi Garcia,39.0,R&d,6176.44,9',
#  '198,Qi David,26.0,SUPPORT,4072.32,7',
#  '199,Wassim Vincent,26.0,Marketing,4968.63,8',
#  '200,Ziad Mercier,61.0,operations,6309.97,16',
#  '201,Wassim Lefebvre,42.0,Finance,6591.61,10',
#  '202,Alice Garcia,55.0,Support,4837.13,12',
#  '203,Claire Simon,64.0,R&D,7920.57,17',
#  '204,Emma Michel,47.0, HR,4637.14,9',
#  '205,Ugo Girard,27.0,finance,4800.92,1',
#  '206,Jamal Richard,39.0,FINANCE,7204.51,13',
#  '207,Claire Laurent,59.0,Marketing,6574.92,19',
#  '208,Qi Lefebvre,56.0, Finance,8147.72,17',
#  '209,Katia Girard,20.0,it,4796.98,2',
#  '210,Yara Girard,58.0,R&D,7290.04,14',
#  '211,Pablo Moreau,38.0,R&d,5771.87,6',
#  '212,Giulia Michel,39.0,Finance,6858.83,12',
#  '213,Emma Garcia,54.0,support,5178.1,17',
#  '214,David Durand,43.0,SALES,5964.73,14',
#  '215,Sara Michel,29.0,Marketing,4243.93,4',
#  '216,Claire David,48.0,Support,4756.61,15',
#  '217,Tom Lefebvre,37.0,Legal  ,5407.13,4',
#  '218,Liam David,21.0,Operations,4068.03,2',
#  '219,Maya Fournier,54.0,Legal,8766.13,13',
#  '220,Maya Garcia,54.0, Operations,6711.7,20',
#  '221,Bob Durand,27.0, IT,4792.53,6',
#  '222,Emma Michel,29.0, Operations,4608.77,5',
#  '223,Qi Morel,,Legal,8268.85,15',
#  '224,Noah Girard,63.0, Sales,6106.49,15',
#  '225,Sara Moreau,56.0,It,6684.81,12',
#  '226,Emma Mercier,21.0,Marketing,3554.86,1',
#  '227,Emma Bertrand,45.0,Marketing  ,4875.28,8',
#  '228,Bob Robert,32.0,support,2603.17,0',
#  '229,Omar Morel,53.0,Operations  ,5779.02,11',
#  '230,Ines Andre,31.0,LEGAL,7295.73,11',
#  '231,Yara Simon,63.0,Marketing  ,6068.42,17',
#  '232,Ines Simon,55.0,hr,4997.43,14',
#  '233,Jamal Durand,64.0,sales,8524.47,24',
#  '234,Giulia Morel,54.0,sales,6046.21,14',
#  '235,Bob Mercier,33.0,Support,3884.91,8',
#  '236,Val Robert,54.0,It,7715.66,17',
#  '237,Pablo Lefebvre,37.0, Marketing,5269.78,8',
#  '238,Hugo Morel,30.0,It,4942.2,3',
#  '239,Ziad Vincent,37.0,FINANCE,6571.37,10',
#  '240,Jamal Roux,52.0,support,3867.1,7',
#  '241,Ziad Petit,29.0,OPERATIONS,,7',
#  '242,Ziad Simon,30.0,MARKETING,4125.15,5',
#  '243,Claire David,30.0,Hr,,11',
#  '244,Hugo Roux,,Sales  ,5655.25,9',
#  '245,Hugo Durand,48.0,HR  ,5266.63,12',
#  '246,Yara Simon,59.0,hr,5833.84,19',
#  '247,Pablo Robert,57.0,Legal  ,8212.9,13',
#  '248,Giulia Moreau,52.0,HR,4853.67,10',
#  '249,Rita Fournier,55.0,Marketing  ,5638.93,13',
#  '250,Giulia Girard,24.0,Legal,5866.67,6',
#  '251,Omar Girard,54.0,IT,6327.42,10',
#  '252,Xia Dubois,21.0,HR,3654.85,1',
#  '253,Pablo Durand,45.0,Sales,6146.43,13',
#  '254,Liam David,43.0,Legal  ,7160.13,9',
#  '255,Liam Petit,53.0,Finance,7387.47,13',
#  '256,Jamal Roux,46.0,SUPPORT,3728.67,7',
#  '257,Giulia Petit,61.0,it,,12',
#  '258,Claire Petit,47.0,It,5710.41,9',
#  '259,Omar Moreau,32.0,support,3561.21,9',
#  '260,Xia Girard,55.0,operations,5281.28,12',
#  '261,Val Fournier,45.0,marketing,5621.09,12',
#  '262,Ugo Mercier,54.0, R&D,5902.1,7',
#  '263,Katia Bertrand,28.0,r&d,6061.93,7',
#  '264,Jamal Robert,22.0,legal,4199.59,0',
#  '265,Ines Dubois,60.0,operations,7056.3,20',
#  '266,Bob Laurent,62.0, R&D,8227.78,17',
#  '267,Xia Mercier,32.0,Support,3438.16,3',
#  '268,Giulia Dubois,49.0,hr,5443.06,17',
#  '269,Rita Michel,43.0,Sales,5091.33,8',
#  '270,Omar Petit,39.0,legal,7731.98,13',
#  '271,Xia Robert,35.0,it,5189.38,6',
#  '272,Katia Moreau,55.0,R&D,7974.44,17',
#  '273,Yara Vincent,48.0,Legal,9125.13,16',
#  '274,Farid Morel,52.0,IT,8522.55,20',
#  '275,Noah Robert,23.0, Marketing,4360.81,5',
#  '276,Ugo Mercier,61.0, Legal,,17',
#  '277,Xia Laurent,37.0,support,4979.07,16',
#  '278,David Petit,28.0,Support,4376.54,8',
#  '279,Claire Garcia,48.0,R&D,5037.48,5',
#  '280,Ugo Lefebvre,24.0,IT  ,5043.67,4',
#  '281,Farid Bernard,46.0, Legal,7147.45,11',
#  '282,Bob Moreau,63.0,MARKETING,6578.75,20',
#  '283,Rita Girard,30.0,IT  ,6087.17,10',
#  '284,Maya Bernard,29.0, Sales,4048.24,4',
#  '285,Katia David,63.0,Finance,7861.02,17',
#  '286,Hugo Bernard,57.0,Operations,5648.57,17',
#  '287,Ugo Laurent,50.0, Legal,8517.14,14',
#  '288,Val David,58.0,Hr,5616.57,15',
#  '289,Wassim Lefebvre,,FINANCE,6960.09,11',
#  '290,Yara Laurent,27.0,HR,4726.11,9',
#  '291,Alice Bernard,54.0,OPERATIONS,6783.57,18',
#  '292,Noah David,54.0,Hr,5914.53,22',
#  '293,Farid Robert,38.0,SALES,5567.38,10',
#  '294,Pablo Bernard,35.0,Operations,5715.45,14',
#  '295,David Robert,19.0,SALES,3514.8,1',
#  '296,Omar Michel,60.0,r&d,8493.83,18',
#  '297,Pablo Michel,44.0, Finance,7701.38,15',
#  '298,Ziad Moreau,43.0,operations,5887.18,11',
#  '299,Sara Morel,62.0,finance,8140.35,17',
#  '300,Omar Simon,45.0,hr,4834.62,12',
#  '301,Wassim Bertrand,23.0,R&D  ,4807.4,2',
#  '302,Noah Morel,42.0,IT,5676.4,10',
#  '303,Yara Moreau,29.0,Operations,4617.95,7',
#  '304,Yara Michel,25.0, R&D,5895.37,7',
#  '305,Wassim Girard,47.0,marketing,5597.88,11',
#  '306,Liam Martin,25.0,Legal  ,6447.86,5',
#  '307,Emma Garcia,40.0,Sales,5256.57,9',
#  '308,Xia Roux,23.0,Operations  ,4699.86,4',
#  '309,David Mercier,34.0,Finance,5411.86,5',
#  '310,Hugo David,,finance,5433.48,6',
#  '311,Omar Girard,43.0,R&D,7565.83,14',
#  '312,Sara Petit,30.0,Support,3988.44,7',
#  '313,Qi Lefebvre,57.0,Operations,5902.9,13',
#  '314,Tom Richard,58.0,Sales,5559.54,12',
#  '315,Farid Garcia,51.0,Finance,7090.6,11',
#  '316,Ugo Morel,54.0, Finance,8194.67,16',
#  '317,Bob Garcia,50.0,It,8157.04,17',
#  '318,Noah Mercier,45.0,legal,7305.16,12',
#  '319,Jamal Durand,33.0,Sales,4757.37,7',
#  '320,Rita Fournier,55.0,HR,6300.79,19',
#  '321,Yara Roux,32.0,SUPPORT,4191.05,10',
#  '322,Bob Roux,41.0,sales,5702.52,12',
#  '323,Giulia Girard,64.0,operations,5847.42,15',
#  '324,Ziad Durand,53.0,OPERATIONS,6246.12,14',
#  '325,Sara Laurent,62.0,Support,5011.44,18',
#  '326,Ines Lefebvre,63.0,Finance  ,8500.46,19',
#  '327,Maya Vincent,55.0,Finance,6748.21,12',
#  '328,Maya Fournier,63.0,Sales,7287.87,20',
#  '329,Yara Bernard,59.0,legal,8157.58,15',
#  '330,Noah Dubois,36.0,Legal,7059.78,9',
#  '331,Ziad Michel,21.0,it,4967.52,3',
#  '332,Omar Roux,46.0,it,7517.84,14',
#  '333,Ines Bernard,35.0,Operations  ,5929.49,13',
#  '334,Jamal Moreau,60.0, R&D,8592.75,18',
#  '335,Hugo Fournier,19.0,Legal  ,4773.94,1',
#  '336,Emma Vincent,33.0,HR,4325.79,5',
#  '337,Emma David,60.0,Finance  ,,18',
#  '338,Farid Roux,32.0,operations,4566.13,7',
#  '339,Claire Petit,26.0,finance,5062.42,4',
#  '340,Hugo Laurent,34.0,HR  ,3866.29,5',
#  '341,Alice Mercier,32.0,Sales,4360.15,5',
#  '342,Ziad Moreau,43.0,Legal,8369.67,14',
#  '343,Liam Michel,43.0,Finance,7221.62,14',
#  '344,Yara Bernard,56.0,It,8056.32,18',
#  '345,Qi Simon,45.0,support,4340.6,10',
#  '346,Ines Bernard,24.0,Sales,4185.65,4',
#  '347,Sara Lefebvre,38.0,HR,4099.58,9',
#  '348,Noah Petit,58.0,Legal,7976.96,14',
#  '349,Alice Robert,29.0,IT,5106.24,5',
#  '350,Farid Garcia,36.0,Finance,6450.49,10',
#  '351,Ines Fournier,35.0,HR,4177.62,9',
#  '352,Bob Vincent,42.0,Finance,7951.67,14',
#  '353,Hugo Fournier,21.0,it,4623.4,3',
#  '354,Farid Durand,64.0,Support  ,4847.72,18',
#  '355,Katia Laurent,55.0, HR,5373.93,13',
#  '356,Bob David,48.0,Hr,5294.39,17',
#  '357,Alice Garcia,37.0, Marketing,4780.34,8',
#  '358,Pablo Dubois,,Support  ,5124.83,13',
#  '359,Wassim Martin,19.0,operations,3378.97,1',
#  '360,Qi Moreau,50.0,R&D,9285.74,22',
#  '361,Hugo Fournier,63.0, R&D,8797.31,20',
#  '362,Emma Lefebvre,23.0,R&D,5341.27,5',
#  '363,Ines Michel,63.0,r&d,8527.92,19',
#  '364,Emma Girard,28.0,HR,4901.99,10',
#  '365,Yara Dubois,38.0,LEGAL,5933.98,5',
#  '366,Wassim Andre,32.0,IT,5970.65,10',
#  '367,Maya Fournier,62.0,It,8049.7,16',
#  '368,Rita Morel,25.0,marketing,,1',
#  '369,Emma Dubois,42.0,R&D,5709.27,9',
#  '370,Alice Bernard,60.0,MARKETING,6054.82,15',
#  '371,David Durand,22.0,Legal,5880.97,4',
#  '372,Maya Mercier,30.0,r&d,5680.84,4',
#  '373,Bob Andre,60.0,MARKETING,6456.83,16',
#  '374,Maya Robert,31.0, R&D,4981.44,5',
#  '375,Ziad Martin,64.0, R&D,8091.23,15',
#  '376,Katia David,,SALES,5865.95,12',
#  '377,Bob Vincent,41.0,Support  ,3258.82,12',
#  '378,Hugo Laurent,22.0,Support,2753.81,4',
#  '379,Liam Richard,34.0,Finance,5151.56,5',
#  '380,Wassim Garcia,55.0, Finance,8947.95,21',
#  '381,Jamal Richard,21.0,Legal,5397.28,3',
#  '382,Katia Andre,27.0,Marketing,4717.85,6',
#  '383,Alice Robert,26.0,Finance  ,5650.51,8',
#  '384,Maya Girard,40.0,HR  ,4853.98,10',
#  '385,Pablo Lefebvre,30.0,OPERATIONS,4318.4,7',
#  '386,Hugo Mercier,43.0,Finance  ,7029.3,10',
#  '387,Sara David,30.0, IT,4254.49,3',
#  '388,David Vincent,40.0,Finance,6608.91,11',
#  '389,Wassim Mercier,47.0,Operations,6064.72,15',
#  '390,Xia Martin,43.0,It,6098.45,9',
#  '391,Liam Morel,25.0,r&d,5414.54,7',
#  '392,Farid Roux,21.0,hr,3972.44,3',
#  '393,Maya Richard,54.0,Hr,6223.7,23',
#  '394,Wassim Martin,60.0,r&d,9542.27,20',
#  '395,Giulia Bertrand,53.0, Support,4922.83,14',
#  '396,Rita Vincent,22.0, Finance,5463.12,4',
#  '397,Pablo Dubois,20.0,HR,3992.23,2',
#  '398,Jamal David,50.0,LEGAL,8515.57,16',
#  '399,Maya Garcia,47.0, Finance,8069.35,16',
#  '400,Bob Robert,24.0,hr,3385.36,4',
#  '401,Rita Durand,52.0,r&d,7021.77,11',
#  '402,Pablo Simon,44.0, HR,5267.62,16',
#  '403,Val Andre,26.0,finance,6037.32,8',
#  '404,Ziad Dubois,21.0,Finance  ,4714.27,0',
#  '405,Emma Andre,39.0,Sales,6246.62,16',
#  '406,Rita Michel,52.0, Sales,5158.53,8',
#  '407,Ziad Bertrand,45.0,HR,5713.33,15',
#  '408,David Girard,37.0,HR  ,4802.89,14',
#  '409,Pablo Girard,21.0,Legal,5549.02,3',
#  '410,Bob David,63.0,Operations,7054.98,18',
#  '411,Katia Simon,36.0,sales,5505.08,13',
#  '412,Emma Simon,39.0,legal,7409.22,10',
#  '413,Noah Vincent,42.0, Support,4234.31,13',
#  '414,Maya Robert,55.0,support,5075.51,17',
#  '415,Bob Roux,42.0,IT  ,6189.62,11',
#  '416,David Mercier,34.0, IT,5609.34,6',
#  '417,Rita Garcia,29.0,Operations,4832.21,9',
#  '418,Maya Durand,55.0,finance,7775.28,16',
#  '419,Ines Lefebvre,51.0,r&d,,19',
#  '420,Ugo Richard,33.0,IT  ,6522.47,9',
#  '421,Ines Bertrand,41.0, R&D,6413.63,9',
#  '422,Maya Girard,19.0,HR  ,3408.05,1',
#  '423,Tom Andre,38.0,SALES,4884.83,9',
#  '424,Ines Laurent,31.0, Sales,6013.21,11',
#  '425,Maya Mercier,62.0,Operations,6612.47,18',
#  '426,Maya David,56.0,it,6702.63,14',
#  '427,Val Morel,61.0, Legal,8596.83,15',
#  '428,Farid Simon,49.0,hr,5567.13,15',
#  '429,Val Michel,33.0,HR,4530.89,6',
#  '430,Liam Laurent,48.0, Sales,6127.82,15',
#  '431,Claire Vincent,51.0,marketing,6629.93,17',
#  '432,Emma Dubois,45.0,Operations  ,6679.03,19',
#  '433,Farid Bernard,40.0,LEGAL,,10',
#  '434,Giulia Richard,50.0,Finance,7240.86,15',
#  '435,Maya Bertrand,43.0,LEGAL,8410.87,15',
#  '436,Yara Fournier,20.0,MARKETING,3542.68,2',
#  '437,Jamal Robert,43.0,HR,4554.62,9',
#  '438,Omar Fournier,40.0,Support,4025.05,7',
#  '439,Liam Dubois,44.0,Finance,7545.63,14',
#  '440,Sara Fournier,26.0,FINANCE,5543.42,4',
#  '441,Yara Morel,57.0,IT  ,,20',
#  '442,David Bertrand,43.0,Legal  ,8040.49,13',
#  '443,Ugo Martin,45.0,sales,5024.21,10',
#  '444,Noah Petit,58.0,support,5139.51,17',
#  '445,Yara Laurent,31.0,support,3959.91,6',
#  '446,Wassim Vincent,34.0,Operations  ,5887.7,14',
#  '447,Pablo Robert,51.0,Hr,6038.54,18',
#  '448,Jamal Laurent,22.0,Legal  ,5649.09,4',
#  '449,Katia Bertrand,,HR  ,3772.67,7',
#  '450,Farid Michel,47.0,OPERATIONS,5983.97,15',
#  '451,Farid Petit,44.0,R&d,7503.94,14',
#  '452,Ugo Richard,27.0,Hr,4181.61,7',
#  '453,Sara Vincent,30.0,Legal  ,5204.32,4',
#  '454,Emma Vincent,26.0,Legal,6370.11,8',
#  '455,Wassim Mercier,55.0, Support,4589.25,15',
#  '456,Qi Andre,46.0,Hr,4647.2,11',
#  '457,Emma Morel,19.0,it,4082.58,1',
#  '458,Claire Vincent,34.0,Operations,5071.6,8',
#  '459,Maya Moreau,48.0,HR,4834.46,10',
#  '460,David Vincent,25.0, IT,5366.21,6',
#  '461,Tom Lefebvre,51.0,Sales,5233.03,10',
#  '462,Hugo Roux,54.0,Operations,5646.34,15',
#  '463,David Petit,19.0, Marketing,4234.15,1',
#  '464,Liam Petit,29.0,IT,4466.52,2',
#  '465,Tom Dubois,26.0,Marketing  ,4752.76,8',
#  '466,Katia Petit,21.0,R&d,4665.6,3',
#  '467,Omar Mercier,27.0,Support,3833.7,7',
#  '468,Sara Vincent,30.0,Support  ,3666.95,7',
#  '469,Tom Andre,51.0,operations,6008.1,16',
#  '470,Ines David,37.0,Operations  ,5076.87,9',
#  '471,Qi Simon,39.0, Support,3397.61,9',
#  '472,Wassim Simon,62.0, Operations,7249.67,20',
#  '473,Wassim Lefebvre,64.0,Operations  ,7085.42,20',
#  '474,Wassim Bertrand,,Support,4221.23,12',
#  '475,Emma Durand,31.0,it,6283.44,8',
#  '476,Bob Simon,53.0,Marketing  ,6910.93,20',
#  '477,Rita Moreau,43.0,Support  ,4963.86,12',
#  '478,Bob David,45.0,R&D,8780.05,20',
#  '479,Xia Laurent,58.0,Marketing  ,6363.06,20',
#  '480,Wassim Lefebvre,56.0,OPERATIONS,5422.2,12',
#  '481,Omar Richard,30.0,HR,4865.78,12',
#  '482,Rita Laurent,29.0,finance,5564.08,6',
#  '483,Bob Robert,57.0,Operations,7458.74,22',
#  '484,Ziad Girard,41.0, Support,5008.01,15',
#  '485,Claire Fournier,45.0,Finance  ,6288.47,9',
#  '486,Katia Michel,37.0,Operations  ,5861.63,11',
#  '487,Alice Petit,47.0,Operations,6139.36,13',
#  '488,Val Michel,26.0,R&D,5405.78,4',
#  '489,Qi Fournier,50.0,Legal,9874.5,20',
#  '490,Farid Morel,19.0,Support  ,2972.28,1',
#  '491,Noah Petit,53.0,Marketing,5937.77,18',
#  '492,Xia Mercier,20.0,FINANCE,4828.25,2',
#  '493,Rita Bernard,35.0,Marketing,4900.18,7',
#  '494,Val Petit,19.0,Support  ,2796.8,1',
#  '495,Claire Garcia,25.0,Support,4162.32,6',
#  '496,Maya David,49.0, IT,7475.83,15',
#  '497,Jamal Lefebvre,38.0,FINANCE,5313.37,7',
#  '498,Alice Morel,28.0,Support,3981.07,8',
#  '499,Jamal Dubois,32.0,operations,4575.52,5',
#  '500,Tom Laurent,26.0, Marketing,5368.69,8',
#  '501,Omar Lefebvre,23.0,Support,3708.41,5',
#  '502,Katia Garcia,61.0,FINANCE,7865.84,16',
#  '503,Pablo Roux,58.0,OPERATIONS,5491.38,14',
#  '504,Noah Richard,39.0,IT,6632.25,11',
#  '505,Emma Mercier,49.0,operations,5435.42,11',
#  '506,Ugo Andre,36.0,HR  ,4712.2,11',
#  '507,Claire Bernard,51.0,it,5795.94,10',
#  '508,Bob Morel,53.0,Sales,6769.08,18',
#  '509,Hugo Girard,27.0,Sales  ,4278.87,4',
#  '510,Hugo Andre,51.0,finance,7886.4,15',
#  '511,Xia Vincent,21.0,Operations,4350.31,3',
#  '512,Val Dubois,42.0,Support  ,4153.75,6',
#  '513,Katia Petit,59.0,support,4780.45,19',
#  '514,Maya Lefebvre,42.0,r&d,5304.29,6',
#  '515,Qi David,41.0,operations,4888.38,8',
#  '516,Omar Richard,23.0, Marketing,4217.78,4',
#  '517,Wassim Petit,45.0,marketing,5396.09,14',
#  '518,Sara Richard,20.0, R&D,4836.82,2',
#  '519,Bob Girard,22.0, Finance,5806.81,4',
#  '520,Ugo Martin,24.0,sales,5000.75,6',
#  '521,Noah Andre,56.0,Finance  ,7808.23,16',
#  '522,Val Michel,57.0,legal,8023.15,14',
#  '523,Qi Fournier,28.0, R&D,5524.6,6',
#  '524,Qi Petit,49.0,HR  ,,10',
#  '525,Ugo Bertrand,45.0,Support,4505.03,12',
#  '526,Ziad David,56.0,Operations,5943.07,18',
#  '527,Emma Laurent,33.0,LEGAL,7032.8,10',
#  '528,Giulia Martin,55.0,IT,6588.71,12',
#  '529,Noah Garcia,28.0, HR,4038.33,4',
#  '530,Liam Andre,62.0,sales,6721.62,16',
#  '531,Liam Morel,49.0,Support  ,4816.68,13',
#  '532,Emma Mercier,33.0,Hr,4153.15,5',
#  '533,Ziad Michel,58.0,Support,4355.83,15',
#  '534,Ziad Bernard,49.0,Finance,7835.93,16',
#  '535,Tom Durand,44.0,r&d,6121.07,9',
#  '536,Ugo Vincent,19.0,Legal,5178.75,1',
#  '537,Ziad Andre,52.0,Support  ,4166.95,13',
#  '538,Alice Richard,36.0, HR,4424.84,10',
#  '539,Alice Bernard,54.0,HR,5811.33,14',
#  '540,Hugo Andre,48.0,Marketing,6152.28,17',
#  '541,Rita Bernard,37.0, Support,4206.38,9',
#  '542,Ziad Girard,63.0,SALES,6502.72,15',
#  '543,Yara Roux,56.0,legal,8917.69,18',
#  '544,Val Moreau,,operations,6120.07,16',
#  '545,Jamal Bernard,62.0,R&D,8005.53,17',
#  '546,Liam Dubois,30.0,sales,5651.65,12',
#  '547,Hugo Moreau,32.0,Sales,5764.59,9',
#  '548,David Bernard,58.0,LEGAL,10244.62,22',
#  '549,Tom Michel,55.0,LEGAL,8924.08,18',
#  '550,Maya Moreau,22.0,FINANCE,4939.33,3',
#  '551,Maya Mercier,48.0,Finance,8371.7,18',
#  '552,Val Dubois,56.0,R&D,8688.14,18',
#  '553,Hugo Laurent,58.0,LEGAL,8559.47,15',
#  '554,Liam David,47.0,Sales,6343.88,14',
#  '555,Xia Laurent,54.0,marketing,5641.37,12',
#  '556,Pablo Martin,45.0,Finance  ,4762.5,2',
#  '557,Katia Vincent,35.0,Sales,4452.1,6',
#  '558,Giulia Laurent,59.0, Legal,9981.95,20',
#  '559,Ziad Laurent,20.0, Operations,3986.88,2',
#  '560,Sara Lefebvre,30.0,Support  ,4288.27,11',
#  '561,Omar Bernard,58.0,R&D,8212.91,15',
#  '562,Noah Lefebvre,23.0,R&D  ,5531.27,5',
#  '563,Ines Andre,36.0, R&D,7220.93,14',
#  '564,Omar Bertrand,30.0,Finance  ,6247.01,9',
#  '565,Wassim Bernard,29.0,Marketing,4801.04,7',
#  '566,Alice David,24.0,Support,3972.91,6',
#  '567,Jamal Moreau,37.0,Marketing,5094.53,9',
#  '568,Val Garcia,49.0,operations,4984.24,8',
#  '569,Wassim Morel,56.0, Finance,6816.22,12',
#  '570,Ugo Lefebvre,38.0,SUPPORT,4373.76,13',
#  '571,Liam Bertrand,28.0,SALES,4803.85,7',
#  '572,Jamal Vincent,19.0,Support,2797.23,1',
#  '573,Ziad Simon,19.0,marketing,3702.15,1',
#  '574,Farid Lefebvre,43.0, R&D,7199.8,12',
#  '575,Ziad Mercier,37.0,Sales,4703.06,8',
#  '576,Farid Robert,26.0,sales,3884.67,4',
#  '577,Katia Martin,22.0,finance,5208.0,4',
#  '578,Wassim Roux,33.0,It,6007.74,9',
#  '579,Liam Roux,40.0,It,7541.46,15',
#  '580,Claire Morel,30.0,Legal,7638.28,10',
#  '581,Yara Moreau,47.0,R&D,8288.2,13',
#  '582,Qi Mercier,49.0,Marketing  ,5370.75,8',
#  '583,Bob Morel,26.0,Support  ,4267.88,7',
#  '584,Giulia Petit,59.0,Marketing,6181.01,16',
#  '585,Ziad Moreau,21.0,IT,3995.86,1',
#  '586,Hugo Richard,24.0,Legal,5549.09,5',
#  '587,Bob Garcia,63.0, Finance,7947.62,16',
#  '588,Ziad Lefebvre,47.0,OPERATIONS,5648.02,13',
#  '589,Bob Vincent,54.0,LEGAL,8585.45,14',
#  '590,Katia Roux,57.0,SALES,7004.71,19',
#  '591,Ines Morel,48.0,Operations,6391.93,17',
#  '592,Tom Garcia,39.0, Marketing,4767.64,10',
#  '593,Val Vincent,28.0, Support,3427.36,5',
#  '594,Val Bernard,27.0,IT,5828.15,8',
#  '595,Sara Lefebvre,61.0,r&d,7346.58,13',
#  '596,Tom Bernard,32.0,IT  ,4528.39,5',
#  '597,Bob Garcia,45.0, Support,4320.23,15',
#  '598,Bob Bernard,23.0, Sales,4139.78,5',
#  '599,Maya Dubois,52.0, Marketing,5195.06,12',
#  '600,Noah Petit,62.0,operations,5823.83,13',
#  '601,Rita David,40.0,SUPPORT,3770.14,9',
#  '602,Rita Michel,45.0, Operations,5392.88,13',
#  '603,Rita Dubois,54.0,R&d,8177.19,17',
#  '604,Alice Durand,57.0,sales,,17',
#  '605,Giulia Michel,63.0, IT,7795.52,20',
#  '606,Emma Petit,48.0,it,6768.98,12',
#  '607,Ines Simon,55.0,Hr,5094.95,10',
#  '608,Farid Vincent,57.0,HR,5335.46,15',
#  '609,Yara Michel,46.0,Operations  ,4992.25,7',
#  '610,Tom Martin,22.0, R&D,5241.9,4',
#  '611,Wassim Moreau,22.0, Finance,3612.76,1',
#  '612,Qi Bernard,46.0, Marketing,5811.09,12',
#  '613,Xia Durand,44.0,support,4741.56,12',
#  '614,Pablo Morel,50.0, Marketing,5598.71,11',
#  '615,Hugo Moreau,36.0,HR  ,4438.56,10',
#  '616,Noah Bertrand,41.0,operations,5796.69,12',
#  '617,Liam Andre,58.0,LEGAL,8992.12,17',
#  '618,Emma Bernard,22.0,HR,4277.5,4',
#  '619,Alice Michel,38.0,hr,4719.86,10',
#  '620,Rita Fournier,54.0,Sales,5451.67,10',
#  '621,Maya Girard,21.0,SUPPORT,3465.57,3',
#  '622,Bob Roux,23.0,IT,5033.7,4',
#  '623,Alice Simon,33.0,R&d,7034.72,12',
#  '624,Tom Morel,30.0,HR,5582.83,11',
#  '625,Hugo Fournier,,SALES,4631.32,6',
#  '626,Ugo Simon,51.0,Marketing,5945.93,14',
#  '627,Rita Laurent,28.0, Marketing,4811.22,6',
#  '628,Val Andre,45.0,MARKETING,5692.42,12',
#  '629,Omar Morel,32.0,finance,5356.28,6',
#  '630,Jamal Fournier,46.0,finance,9107.82,21',
#  '631,Katia Bernard,53.0,Support  ,4872.21,16',
#  '632,Alice Michel,45.0,R&D  ,7308.76,11',
#  '633,Ines Robert,25.0, Marketing,4770.85,7',
#  '634,Sara Andre,57.0,Marketing,6614.63,16',
#  '635,Emma Fournier,64.0,legal,8765.54,17',
#  '636,Giulia Moreau,45.0,IT  ,6588.03,12',
#  '637,Val Dubois,23.0,Marketing  ,5069.35,5',
#  '638,Katia Roux,46.0,MARKETING,5569.35,12',
#  '639,Maya Andre,52.0,Support,3956.66,11',
#  '640,Bob Moreau,53.0,Support  ,4618.25,11',
#  '641,Bob Dubois,47.0,Sales,5752.83,11',
#  '642,Jamal Andre,63.0,IT  ,7502.31,16',
#  '643,Qi Petit,56.0,Finance,8723.73,20',
#  '644,Alice Richard,56.0,LEGAL,9574.11,21',
#  '645,Wassim Lefebvre,64.0,Finance,8309.53,18',
#  '646,Qi David,58.0,SUPPORT,5189.13,19',
#  '647,Sara Mercier,29.0,FINANCE,6231.75,9',
#  '648,Xia Roux,59.0,SALES,,19',
#  '649,Alice Roux,50.0, Legal,7871.3,13',
#  '650,Val Vincent,,LEGAL,6985.28,9',
#  '651,Tom Lefebvre,32.0,Support,4251.42,10',
#  '652,Val Girard,40.0,Sales  ,5754.37,12',
#  '653,Jamal Andre,30.0,SUPPORT,4335.1,12',
#  '654,Katia Garcia,23.0,R&D,4823.21,5',
#  '655,Wassim Laurent,52.0, Operations,5816.19,13',
#  '656,Xia Lefebvre,24.0,SUPPORT,3286.96,2',
#  '657,Noah Andre,35.0, Operations,3344.79,0',
#  '658,Pablo Fournier,50.0,legal,8078.56,16',
#  '659,Alice Petit,48.0,It,6533.42,12',
#  '660,Noah Durand,,OPERATIONS,4531.63,7',
#  '661,Ines Bernard,,SALES,4988.85,8',
#  '662,Maya Girard,30.0,It,6733.57,10',
#  '663,Ziad Durand,49.0,Finance,8026.16,15',
#  '664,Ziad Bertrand,52.0,it,7319.05,13',
#  '665,Sara Mercier,41.0,Operations,5778.95,13',
#  '666,Ugo Morel,55.0,FINANCE,7400.89,14',
#  '667,Wassim Michel,36.0,IT,5721.19,7',
#  '668,Giulia Fournier,30.0,Sales,6140.91,12',
#  '669,Qi Martin,51.0,LEGAL,8885.35,16',
#  '670,Yara Michel,25.0,Finance  ,5273.92,7',
#  '671,Bob Roux,64.0, R&D,8648.22,19',
#  '672,Claire Michel,21.0,LEGAL,,3',
#  '673,Ugo Dubois,31.0,Operations,5255.88,9',
#  '674,Ines Robert,36.0, Finance,8248.18,15',
#  '675,Liam Morel,36.0,Operations,6073.77,13',
#  '676,Jamal Andre,53.0,Operations,5764.91,13',
#  '677,Maya Durand,46.0,HR  ,4854.3,9',
#  '678,Wassim Roux,38.0,Operations,5203.29,9',
#  '679,Yara Roux,24.0,Finance  ,5058.11,6',
#  '680,Ugo Roux,33.0,LEGAL,7305.82,11',
#  '681,Maya Richard,39.0,Operations,5221.52,10',
#  '682,Farid Simon,57.0,Operations,5548.44,13',
#  '683,Katia Morel,38.0, HR,4217.97,7',
#  '684,Farid Vincent,23.0,R&d,5383.19,3',
#  '685,Sara Michel,63.0, Support,5600.57,18',
#  '686,Pablo Petit,39.0,Legal,5610.9,5',
#  '687,Tom Petit,39.0, R&D,5655.8,6',
#  '688,Yara Lefebvre,28.0,It,5040.8,6',
#  '689,Giulia Dubois,38.0,Operations,3896.54,4',
#  '690,Wassim Garcia,56.0,HR,6704.86,24',
#  '691,Bob Garcia,22.0,SUPPORT,3482.04,4',
#  '692,Alice Moreau,63.0,R&d,7334.43,14',
#  '693,Rita Dubois,49.0,Finance,8272.9,16',
#  '694,Emma Simon,27.0,Finance  ,6401.59,9',
#  '695,Noah Robert,27.0, HR,3757.54,5',
#  '696,Noah Andre,48.0,finance,6347.52,9',
#  '697,Noah Andre,55.0, IT,6205.63,10',
#  '698,Sara Garcia,21.0,IT  ,4025.39,1',
#  '699,Claire Robert,36.0,Support,4106.46,9',
#  '700,Ugo Mercier,62.0,HR,4860.39,14',
#  '701,Rita Martin,48.0,LEGAL,7073.16,10',
#  '702,Jamal Richard,63.0,IT,8607.46,22',
#  '703,Ugo Vincent,55.0,FINANCE,10111.31,24',
#  '704,Pablo Bernard,51.0,FINANCE,8913.81,19',
#  '705,Ines Martin,57.0,hr,6177.37,18',
#  '706,Ines Moreau,30.0,legal,6531.42,10',
#  '707,Tom Robert,45.0,legal,7660.65,13',
#  '708,Sara Garcia,60.0,It,8072.88,16',
#  '709,Jamal Vincent,33.0,Support,4041.59,6',
#  '710,Alice Simon,43.0, Legal,5889.58,8',
#  '711,Ugo Garcia,58.0,R&D,8947.89,21',
#  '712,Ines Lefebvre,48.0,r&d,7066.39,14',
#  '713,Qi Michel,39.0,Finance,,6',
#  '714,Qi Petit,41.0,Legal,,12',
#  '715,Bob Andre,57.0,marketing,5320.9,13',
#  '716,Maya Mercier,26.0,Finance  ,5463.93,6',
#  '717,Omar Laurent,63.0,R&D,9186.67,22',
#  '718,Ines Durand,43.0,R&d,6931.67,11',
#  '719,Claire Vincent,58.0,Marketing,5949.85,13',
#  '720,Giulia Andre,47.0,HR,4983.21,13',
#  '721,Yara Roux,50.0,IT,7865.27,16',
#  '722,Emma Michel,55.0,R&d,9010.95,20',
#  '723,Xia Bernard,33.0, Support,4815.48,15',
#  '724,Rita Garcia,62.0,OPERATIONS,6485.57,17',
#  '725,Rita Michel,48.0,Hr,4872.27,13',
#  '726,Val Dubois,63.0,Sales  ,6690.8,16',
#  '727,Omar Dubois,21.0,Finance,5438.24,3',
#  '728,Ziad Morel,50.0,Sales,4879.62,8',
#  '729,Katia Durand,21.0,Operations  ,4125.76,3',
#  '730,Rita Robert,23.0, Marketing,4438.07,5',
#  '731,Bob Moreau,19.0,Finance,4614.81,1',
#  '732,Tom Richard,25.0,hr,4545.17,7',
#  '733,Noah Michel,39.0,r&d,7873.43,14',
#  '734,Yara Durand,40.0,FINANCE,7382.86,13',
#  '735,Rita Richard,34.0, Legal,7061.07,10',
#  '736,Maya Richard,50.0, IT,7097.55,14',
#  '737,Jamal Bertrand,63.0,legal,9559.28,19',
#  '738,Farid Andre,57.0,IT,8059.55,17',
#  '739,Liam Bertrand,54.0,IT,7449.39,15',
#  '740,Yara Morel,33.0,Support,3693.86,5',
#  '741,Ziad Robert,50.0,LEGAL,9059.78,16',
#  '742,Giulia Bertrand,40.0,Sales,4177.71,6',
#  '743,Rita Richard,20.0, Finance,4773.97,2',
#  '744,Sara Michel,31.0,r&d,5478.58,8',
#  '745,David Moreau,31.0,R&d,6029.29,7',
#  '746,Emma Dubois,30.0,LEGAL,6425.65,7',
#  '747,Giulia Michel,21.0,Finance,4891.64,3',
#  '748,Noah Richard,33.0, Operations,5272.81,12',
#  '749,Farid Girard,33.0, Support,4985.88,14',
#  '750,Pablo Roux,19.0, Sales,3114.11,1',
#  '751,Hugo Girard,55.0,Finance  ,8253.83,18',
#  '752,Yara Fournier,46.0,It,5913.41,9',
#  '753,Pablo Moreau,54.0,HR,4938.94,15',
#  '754,Jamal Moreau,20.0,HR  ,3612.41,2',
#  '755,Sara Martin,48.0,LEGAL,7534.88,14',
#  '756,Ugo Roux,59.0,It,9112.82,22',
#  '757,Yara Laurent,55.0,Support  ,4532.34,17',
#  '758,Bob Fournier,22.0,operations,4363.77,4',
#  '759,Ugo Morel,54.0,HR,5063.54,14',
#  '760,Ugo Vincent,33.0,Marketing,5139.13,6',
#  '761,Claire Garcia,47.0,Operations  ,5061.71,9',
#  '762,Rita Simon,58.0,Legal,8210.68,13',
#  '763,Giulia Roux,24.0,hr,4119.41,5',
#  '764,Ines Petit,50.0,Finance,,15',
#  '765,Val Morel,49.0,Finance,7326.82,12',
#  '766,Alice Moreau,60.0,Support,5138.41,15',
#  '767,Sara Mercier,54.0,support,4646.14,13',
#  '768,Ziad Laurent,49.0,MARKETING,5698.27,12',
#  '769,Omar Richard,64.0,Finance  ,7938.11,16',
#  '770,Ziad Robert,34.0,FINANCE,8620.9,16',
#  '771,Farid Dubois,64.0, Support,5456.64,20',
#  '772,Farid Morel,26.0,Sales,4853.56,8',
#  '773,Katia Robert,53.0,IT,7698.9,17',
#  '774,Yara Girard,55.0,Finance,6848.02,14',
#  '775,Bob Robert,26.0,Support,4004.01,6',
#  '776,Katia Durand,56.0,Marketing,5113.52,10',
#  '777,Rita Roux,51.0,HR,5054.52,11',
#  '778,Val Garcia,28.0,R&D,,7',
#  '779,Liam Simon,54.0,Legal,9693.14,19',
#  '780,Jamal Richard,45.0,R&d,8106.79,15',
#  '781,Qi Michel,56.0,Hr,5410.99,16',
#  '782,Farid Morel,64.0,LEGAL,7344.38,12',
#  '783,Rita Vincent,38.0,IT,6419.86,12',
#  '784,Ziad Martin,35.0,Finance  ,6548.01,8',
#  '785,Jamal Bertrand,,Finance,7971.42,17',
#  '786,Claire Andre,56.0,Operations  ,5579.27,12',
#  '787,David Garcia,55.0,Support,5185.59,18',
#  '788,Wassim Robert,29.0,Operations,5292.65,10',
#  '789,Jamal Simon,59.0,Support,5259.64,20',
#  '790,Tom Richard,39.0,Support  ,4396.42,15',
#  '791,Wassim Garcia,,HR,4430.76,10',
#  '792,Yara Vincent,40.0,r&d,7234.67,13',
#  '793,Ziad Morel,53.0,Support,4225.88,14',
#  '794,David Robert,49.0, IT,6795.01,11',
#  '795,Qi Michel,64.0,Finance  ,8446.6,16',
#  '796,Emma Moreau,27.0,Sales,6018.48,9',
#  '797,Claire Martin,46.0,Legal,8177.83,14',
#  '798,Pablo Petit,21.0, Sales,4180.03,3',
#  '799,Giulia Girard,30.0,MARKETING,4815.8,8',
#  '800,Sara Garcia,29.0,Operations,4957.28,11',
#  '801,David Girard,52.0, IT,7491.45,15',
#  '802,Alice Petit,51.0,Marketing  ,5886.23,16',
#  '803,David Richard,43.0,OPERATIONS,5195.5,9',
#  '804,David Roux,52.0,HR,6203.37,18',
#  '805,Claire Michel,26.0,Legal,5759.57,4',
#  '806,Hugo Morel,37.0,R&d,7290.09,13',
#  '807,Val Garcia,19.0,Finance  ,4527.2,1',
#  '808,Val Bernard,28.0,hr,4143.81,4',
#  '809,Claire Garcia,40.0,Marketing,6230.31,13',
#  '810,Xia Vincent,64.0,Sales,6599.41,18',
#  '811,Liam Vincent,50.0,R&d,7067.86,12',
#  '812,Pablo Moreau,20.0,finance,4817.91,2',
#  '813,Maya Andre,28.0, Operations,4916.35,6',
#  '814,Yara Vincent,31.0, Legal,6659.04,7',
#  '815,Rita Martin,46.0,It,6976.65,14',
#  '816,Omar Durand,30.0,It,4232.5,2',
#  '817,Noah Robert,64.0, Sales,6527.23,14',
#  '818,Val Morel,49.0, Legal,7553.31,12',
#  '819,Maya Andre,37.0,OPERATIONS,5264.77,10',
#  '820,Ziad Girard,59.0,IT,7634.06,16',
#  '821,Bob Mercier,34.0,MARKETING,5298.29,9',
#  '822,David Michel,20.0, Finance,4740.21,2',
#  '823,Noah Laurent,63.0,IT,7752.04,17',
#  '824,Sara Petit,25.0,Legal  ,5870.19,6',
#  '825,Katia Richard,42.0,Sales,5961.55,13',
#  '826,Rita Dubois,35.0,Sales  ,7094.88,17',
#  '827,Claire Girard,56.0,hr,5495.7,15',
#  '828,Liam Bernard,51.0,Sales,6098.77,15',
#  '829,Ines Andre,48.0, Support,3987.13,11',
#  '830,Farid Girard,32.0,Legal  ,5586.41,6',
#  '831,Rita Andre,55.0,r&d,7695.71,15',
#  '832,Emma Mercier,46.0,Sales,5318.05,8',
#  '833,Ines Simon,35.0,Finance,6166.91,9',
#  '834,Hugo Simon,50.0,legal,7242.11,11',
#  '835,Ines Robert,35.0,IT,5965.46,10',
#  '836,Xia Vincent,22.0,It,4783.0,4',
#  '837,Liam Mercier,44.0,HR  ,5511.66,17',
#  '838,Qi Petit,61.0,Support,4754.96,20',
#  '839,Hugo Andre,39.0,hr,4909.2,9',
#  '840,Noah Dubois,25.0, Finance,6617.97,7',
#  '841,Bob Vincent,42.0,support,4180.41,11',
#  '842,Ines Robert,, Operations,4996.1,12',
#  '843,Bob Mercier,63.0,IT  ,8398.08,21',
#  '844,Wassim Garcia,53.0,Hr,5520.5,19',
#  '845,Ines Simon,34.0,HR,4848.08,7',
#  '846,Ziad Lefebvre,21.0,R&D  ,5041.19,3',
#  '847,Noah Michel,25.0, R&D,5465.29,7',
#  '848,Xia Morel,48.0,Operations,4891.52,11',
#  '849,Ziad Lefebvre,19.0,finance,4776.66,1',
#  '850,Hugo Fournier,57.0,Finance  ,7030.61,14',
#  '851,Emma Laurent,62.0,FINANCE,7602.53,15',
#  '852,Farid David,55.0,R&D  ,8760.4,16',
#  '853,Hugo Bernard,31.0, Legal,7164.65,8',
#  '854,Ines Robert,,Hr,5460.4,13',
#  '855,Val Vincent,33.0,HR,4230.02,8',
#  '856,Xia Vincent,27.0,R&D  ,5485.38,5',
#  '857,Val Dubois,30.0, R&D,5971.61,7',
#  '858,Omar Moreau,,OPERATIONS,5575.81,14',
#  '859,Wassim David,64.0, Marketing,6210.38,15',
#  '860,Bob Durand,34.0, Operations,4570.96,6',
#  '861,Wassim Durand,35.0,it,5531.62,7',
#  '862,Rita Durand,35.0,Finance,7136.2,11',
#  '863,Katia Fournier,28.0,R&D,6139.53,7',
#  '864,Xia Garcia,37.0, R&D,6945.52,12',
#  '865,Katia Bertrand,39.0,Finance  ,6252.4,10',
#  '866,Ugo Roux,31.0,IT  ,6374.3,10',
#  '867,Omar Bertrand,50.0,Hr,5751.41,17',
#  '868,David Robert,41.0, HR,5874.98,16',
#  '869,Ines Girard,56.0,Marketing,6159.66,16',
#  '870,Hugo Vincent,40.0, HR,5473.68,15',
#  '871,David Michel,20.0,FINANCE,5035.69,2',
#  '872,Tom Mercier,40.0,IT  ,7217.24,15',
#  '873,Xia Girard,32.0,Finance  ,6651.45,12',
#  '874,Claire Morel,24.0,R&D,5511.5,5',
#  '875,Alice Dubois,43.0,Finance,6818.51,12',
#  '876,Jamal Vincent,38.0,R&D,7327.95,14',
#  '877,Qi Dubois,47.0,Legal,8174.97,15',
#  '878,Ziad Garcia,46.0,Finance  ,6963.01,12',
#  '879,Hugo Lefebvre,50.0,Finance,6526.14,10',
#  '880,Ziad Vincent,28.0,Sales,5354.81,10',
#  '881,Jamal Girard,54.0,IT,7562.15,16',
#  '882,Omar Mercier,41.0,Sales  ,5723.86,11',
#  '883,Omar Richard,44.0,Finance  ,7837.33,15',
#  '884,Omar Mercier,58.0,legal,8663.75,17',
#  '885,Farid Bernard,,sales,7629.79,20',
#  '886,Ugo Vincent,63.0,LEGAL,8386.71,14',
#  '887,Tom Andre,63.0,operations,5642.31,15',
#  '888,Emma Martin,26.0,Marketing,,8',
#  '889,Ugo Robert,46.0,Marketing,5663.57,16',
#  '890,Emma Vincent,20.0,R&d,5112.43,2',
#  '891,Pablo Martin,56.0,LEGAL,8910.48,16',
#  '892,Alice Petit,45.0,R&D,7400.79,15',
#  '893,Bob Vincent,50.0,R&d,6319.62,9',
#  '894,Hugo Durand,20.0,Support,3363.03,2',
#  '895,Pablo Petit,58.0,LEGAL,,19',
#  '896,Xia Dubois,41.0, Legal,6715.4,8',
#  '897,Wassim Mercier,27.0,Legal  ,6517.99,9',
#  '898,Ugo Garcia,29.0,legal,5890.62,6',
#  '899,Farid Dubois,57.0,finance,6626.15,10',
#  '900,Giulia Morel,20.0, IT,4620.83,2',
#  '901,Bob Bernard,46.0,OPERATIONS,6021.21,14',
#  '902,Ziad Garcia,54.0,IT  ,7470.73,15',
#  '903,David Durand,48.0, Legal,9062.86,18',
#  '904,Ziad Petit,21.0,SUPPORT,3351.68,3',
#  '905,Farid Simon,51.0,legal,6586.13,8',
#  '906,David Dubois,45.0,LEGAL,7585.76,12',
#  '907,Qi Richard,36.0,hr,4501.39,6',
#  '908,Yara Fournier,33.0, R&D,7082.07,11',
#  '909,Ziad Mercier,20.0,Operations,3681.61,0',
#  '910,Claire Michel,44.0,Operations  ,5859.65,14',
#  '911,Ugo Robert,59.0,It,8772.8,22',
#  '912,Maya Mercier,38.0, Support,3943.84,10',
#  '913,Tom Robert,47.0,R&d,5867.13,9',
#  '914,Wassim Garcia,31.0,R&D  ,6274.39,9',
#  '915,Xia Robert,53.0,Support  ,4809.42,14',
#  '916,Farid Martin,53.0, IT,6737.58,13',
#  '917,David Durand,35.0,Operations,4659.06,8',
#  '918,Omar Simon,48.0,IT  ,6826.65,12',
#  '919,Ugo Mercier,57.0, Support,5171.67,16',
#  '920,Val Robert,52.0,R&D,7418.97,14',
#  '921,Omar Petit,64.0,finance,7889.17,15',
#  '922,Pablo Dubois,23.0,Legal,5808.43,4',
#  '923,Ines Girard,59.0,Legal,8029.53,13',
#  '924,Farid Robert,27.0, Support,3511.72,4',
#  '925,David Dubois,49.0,Legal,8435.65,15',
#  '926,Tom Bertrand,26.0,HR,4181.28,5',
#  '927,Liam Simon,50.0,SALES,6429.13,15',
#  '928,Jamal Dubois,50.0,Finance,8444.95,18',
#  '929,Sara Simon,40.0,legal,7285.91,12',
#  '930,Qi Lefebvre,47.0, Legal,7472.13,12',
#  '931,Val Andre,43.0,R&d,7379.2,12',
#  '932,Xia Laurent,29.0, HR,3903.21,7',
#  '933,Ugo Petit,24.0, Support,4109.63,6',
#  '934,Qi Dubois,51.0,Legal,8308.32,15',
#  '935,Ines Dubois,64.0,MARKETING,6465.13,20',
#  '936,Maya Girard,50.0, IT,7030.36,14',
#  '937,Katia David,24.0,SALES,4690.52,6',
#  '938,Yara Bernard,38.0,finance,7616.18,15',
#  '939,Alice Durand,43.0,Sales,6096.7,13',
#  '940,Bob Dubois,57.0,Marketing,5500.07,13',
#  '941,Ines Durand,,Operations,5503.84,12',
#  '942,Ines Morel,34.0,Hr,4265.82,10',
#  '943,Claire Lefebvre,32.0,support,3917.27,9',
#  '944,Rita Bertrand,47.0,Support  ,5302.52,18',
#  '945,Farid Martin,49.0,IT  ,7085.59,13',
#  '946,Giulia Girard,37.0,Support,4938.66,15',
#  '947,Wassim Petit,54.0,FINANCE,9125.44,21',
#  '948,Val Michel,64.0,Sales,6665.98,16',
#  '949,Tom Michel,63.0,IT,,22',
#  '950,Val Richard,54.0,R&D  ,8473.99,19',
#  '951,Ugo Bernard,20.0,Support,2895.03,2',
#  '952,Tom Garcia,30.0,R&D,6375.42,11',
#  '953,Giulia Roux,33.0,it,5474.8,9',
#  '954,Claire Andre,64.0,Sales,8026.02,19',
#  '955,Wassim Andre,19.0, Marketing,4284.96,1',
#  '956,Qi Vincent,54.0,finance,8671.22,17',
#  '957,Claire Girard,23.0,Finance  ,5951.49,5',
#  '958,Ziad Laurent,62.0,Marketing  ,7714.89,25',
#  '959,Rita Roux,46.0,It,5203.81,8',
#  '960,Noah Laurent,62.0,HR  ,5219.74,14',
#  '961,Hugo Durand,45.0, Sales,5347.1,10',
#  '962,Ziad Martin,63.0,MARKETING,6214.35,16',
#  '963,Claire Lefebvre,20.0,HR,3368.43,0',
#  '964,Ines Moreau,49.0,hr,5533.15,14',
#  '965,Claire Andre,25.0,Legal,5260.38,4',
#  '966,Maya Michel,27.0,Hr,4765.18,9',
#  '967,Claire Petit,54.0,It,8588.23,20',
#  '968,Hugo Andre,48.0,IT,6336.0,9',
#  '969,Ugo Mercier,48.0,IT  ,,9',
#  '970,Claire Girard,55.0, Marketing,6734.54,18',
#  '971,Omar Richard,27.0,Marketing  ,4778.61,8',
#  '972,Yara Garcia,56.0,SALES,6857.62,19',
#  '973,Jamal Garcia,52.0, IT,5966.49,10',
#  '974,Bob Bertrand,31.0,operations,5646.89,13',
#  '975,Val Vincent,57.0,LEGAL,7591.53,14',
#  '976,Noah Michel,25.0,Finance,4909.92,2',
#  '977,Ugo Moreau,48.0,MARKETING,5364.28,12',
#  '978,Ziad David,44.0,Marketing,6992.75,16',
#  '979,Rita Petit,37.0,Finance,5835.0,6',
#  '980,Giulia Dubois,30.0,sales,5429.41,9',
#  '981,Farid Dubois,,It,6089.79,12',
#  '982,Ugo Petit,32.0, Operations,5069.16,8',
#  '983,Ziad Andre,64.0,r&d,8826.91,19',
#  '984,Rita David,39.0, Operations,3697.6,4',
#  '985,Sara Dubois,37.0,support,4060.9,11',
#  '986,Qi Girard,32.0,legal,6059.6,8',
#  '987,Qi David,42.0,Support  ,3962.97,8',
#  '988,Pablo Vincent,36.0,legal,5851.15,6',
#  '989,Hugo Dubois,34.0,LEGAL,6476.01,7',
#  '990,Ines Morel,27.0,HR,4029.15,7',
#  '991,Omar Fournier,46.0,OPERATIONS,5296.48,10',
#  '992,Maya Martin,47.0, Finance,7719.73,13',
#  '993,Qi Morel,36.0,hr,4779.24,11',
#  '994,Katia Dubois,35.0,Operations  ,5381.64,8',
#  '995,Tom Robert,35.0,Support,4453.57,12',
#  '996,Maya Girard,49.0,it,5015.64,8',
#  '997,Hugo Dubois,33.0,Legal,5487.71,4',
#  '998,Katia Bernard,31.0, Operations,4149.65,2',
#  '999,Alice Garcia,55.0,Finance  ,8027.42,17',
#  ...]

# %% [markdown]
# #### 🧩 Exercices

# %% [markdown]
# > Ne récupérer que les employés du département IT.\
# > Indice : .map(), .filter(), .split()
#
# ```bash
# Exemple :
#
# [['22', 'Alice Bernard', '33.0', 'IT', '6231.15', '10'],
#  ['32', 'Hugo Girard', '58.0', 'IT', '8616.31', '20'],
#  ['40', 'Emma Morel', '42.0', 'IT', '6115.84', '10'],
#  ['72', 'Tom Petit', '41.0', 'IT', '5449.79', '7'],
#  ['83', 'Ines Durand', '54.0', 'IT', '7555.4', '13']]
#  ```

# %%
sc = spark.sparkContext

rdd = sc.textFile("./data/employees.csv")
rdd = rdd.map(lambda x: x.split(",")).filter(lambda x: x[3] == "IT")
display(rdd.collect())
# Out:
# [['22', 'Alice Bernard', '33.0', 'IT', '6231.15', '10'],
#  ['32', 'Hugo Girard', '58.0', 'IT', '8616.31', '20'],
#  ['40', 'Emma Morel', '42.0', 'IT', '6115.84', '10'],
#  ['72', 'Tom Petit', '41.0', 'IT', '5449.79', '7'],
#  ['83', 'Ines Durand', '54.0', 'IT', '7555.4', '13'],
#  ['148', 'Xia Lefebvre', '24.0', 'IT', '5111.25', '6'],
#  ['188', 'Ziad Dubois', '39.0', 'IT', '6933.21', '14'],
#  ['251', 'Omar Girard', '54.0', 'IT', '6327.42', '10'],
#  ['274', 'Farid Morel', '52.0', 'IT', '8522.55', '20'],
#  ['302', 'Noah Morel', '42.0', 'IT', '5676.4', '10'],
#  ['349', 'Alice Robert', '29.0', 'IT', '5106.24', '5'],
#  ['366', 'Wassim Andre', '32.0', 'IT', '5970.65', '10'],
#  ['464', 'Liam Petit', '29.0', 'IT', '4466.52', '2'],
#  ['504', 'Noah Richard', '39.0', 'IT', '6632.25', '11'],
#  ['528', 'Giulia Martin', '55.0', 'IT', '6588.71', '12'],
#  ['585', 'Ziad Moreau', '21.0', 'IT', '3995.86', '1'],
#  ['594', 'Val Bernard', '27.0', 'IT', '5828.15', '8'],
#  ['622', 'Bob Roux', '23.0', 'IT', '5033.7', '4'],
#  ['667', 'Wassim Michel', '36.0', 'IT', '5721.19', '7'],
#  ['702', 'Jamal Richard', '63.0', 'IT', '8607.46', '22'],
#  ['721', 'Yara Roux', '50.0', 'IT', '7865.27', '16'],
#  ['738', 'Farid Andre', '57.0', 'IT', '8059.55', '17'],
#  ['739', 'Liam Bertrand', '54.0', 'IT', '7449.39', '15'],
#  ['773', 'Katia Robert', '53.0', 'IT', '7698.9', '17'],
#  ['783', 'Rita Vincent', '38.0', 'IT', '6419.86', '12'],
#  ['820', 'Ziad Girard', '59.0', 'IT', '7634.06', '16'],
#  ['823', 'Noah Laurent', '63.0', 'IT', '7752.04', '17'],
#  ['835', 'Ines Robert', '35.0', 'IT', '5965.46', '10'],
#  ['881', 'Jamal Girard', '54.0', 'IT', '7562.15', '16'],
#  ['949', 'Tom Michel', '63.0', 'IT', '', '22'],
#  ['968', 'Hugo Andre', '48.0', 'IT', '6336.0', '9'],
#  ['1001', 'Katia Girard', '55.0', 'IT', '7078.78', '17'],
#  ['1032', 'Maya Dubois', '34.0', 'IT', '6672.51', '13'],
#  ['1057', 'Val Girard', '25.0', 'IT', '6055.64', '7'],
#  ['1177', 'Qi Richard', '44.0', 'IT', '6686.92', '14'],
#  ['1191', 'Pablo Petit', '28.0', 'IT', '5503.15', '8'],
#  ['1260', 'Farid Laurent', '49.0', 'IT', '6359.84', '12'],
#  ['1311', 'Claire Girard', '59.0', 'IT', '7926.31', '18'],
#  ['1326', 'Sara Durand', '34.0', 'IT', '6089.37', '10'],
#  ['1335', 'Val Simon', '53.0', 'IT', '6596.47', '15'],
#  ['1351', 'Giulia David', '61.0', 'IT', '7229.39', '16'],
#  ['1370', 'Alice Andre', '53.0', 'IT', '6813.35', '13'],
#  ['1389', 'Hugo Martin', '20.0', 'IT', '4073.33', '2'],
#  ['1435', 'Val Richard', '56.0', 'IT', '7105.33', '13'],
#  ['1442', 'Maya Simon', '33.0', 'IT', '5337.2', '9'],
#  ['1489', 'Claire Martin', '62.0', 'IT', '6759.83', '15'],
#  ['1520', 'Alice David', '45.0', 'IT', '6411.76', '9'],
#  ['1530', 'Maya Vincent', '52.0', 'IT', '9395.4', '23'],
#  ['1540', 'Yara Garcia', '27.0', 'IT', '5478.58', '9'],
#  ['1695', 'Pablo Bernard', '47.0', 'IT', '6584.38', '11'],
#  ['1770', 'Claire Robert', '42.0', 'IT', '6660.0', '11'],
#  ['1781', 'Giulia Laurent', '46.0', 'IT', '5949.22', '10'],
#  ['1797', 'Maya Garcia', '33.0', 'IT', '7657.56', '15'],
#  ['1816', 'Rita Laurent', '20.0', 'IT', '4194.72', '1'],
#  ['1836', 'Bob Andre', '31.0', 'IT', '5579.92', '10'],
#  ['1848', 'Noah Durand', '59.0', 'IT', '7511.06', '15'],
#  ['1920', 'Sara Robert', '52.0', 'IT', '8294.09', '17'],
#  ['1925', 'Yara Martin', '20.0', 'IT', '4530.35', '2'],
#  ['1947', 'Val Lefebvre', '37.0', 'IT', '7086.85', '11'],
#  ['1956', 'Xia Bertrand', '58.0', 'IT', '7029.22', '15'],
#  ['1963', 'Bob Dubois', '52.0', 'IT', '7332.05', '16'],
#  ['1970', 'Wassim Martin', '51.0', 'IT', '6704.87', '11'],
#  ['2040', 'Yara Vincent', '36.0', 'IT', '5928.33', '8'],
#  ['2077', 'Tom Dubois', '55.0', 'IT', '6811.04', '12'],
#  ['2108', 'Ziad Petit', '47.0', 'IT', '5745.28', '9'],
#  ['2140', 'Katia Lefebvre', '31.0', 'IT', '5533.3', '8'],
#  ['2186', 'Qi Fournier', '64.0', 'IT', '6319.03', '12'],
#  ['2240', 'Val Garcia', '33.0', 'IT', '4831.95', '6'],
#  ['2246', 'Alice Lefebvre', '44.0', 'IT', '5009.48', '6'],
#  ['2253', 'Ziad Durand', '60.0', 'IT', '7987.59', '19'],
#  ['2282', 'Liam Garcia', '38.0', 'IT', '5065.47', '6'],
#  ['2309', 'Bob Lefebvre', '59.0', 'IT', '6775.33', '15'],
#  ['2329', 'David Moreau', '50.0', 'IT', '6671.0', '13'],
#  ['2359', 'Farid Petit', '55.0', 'IT', '7115.77', '14'],
#  ['2453', 'Noah Lefebvre', '20.0', 'IT', '4765.67', '2'],
#  ['2458', 'David Andre', '40.0', 'IT', '7332.65', '12'],
#  ['2494', 'Yara Roux', '61.0', 'IT', '7661.85', '16'],
#  ['2526', 'Rita Roux', '56.0', 'IT', '6919.6', '15'],
#  ['2528', 'Farid Simon', '35.0', 'IT', '6238.86', '12'],
#  ['2533', 'Tom Michel', '22.0', 'IT', '5006.85', '4'],
#  ['2549', 'Sara Petit', '50.0', 'IT', '7200.97', '12'],
#  ['2609', 'David David', '43.0', 'IT', '5454.25', '8'],
#  ['2612', 'Claire Michel', '26.0', 'IT', '5219.91', '8'],
#  ['2661', 'Jamal Michel', '33.0', 'IT', '6107.86', '11'],
#  ['2778', 'Pablo Bertrand', '47.0', 'IT', '6488.98', '13'],
#  ['2787', 'Yara Richard', '34.0', 'IT', '4602.51', '3'],
#  ['2791', 'Qi Fournier', '46.0', 'IT', '6008.2', '9'],
#  ['2837', 'Jamal Vincent', '47.0', 'IT', '7748.31', '17'],
#  ['2841', 'Noah Richard', '21.0', 'IT', '4965.48', '3'],
#  ['2845', 'Qi Bertrand', '56.0', 'IT', '', '15'],
#  ['2893', 'Ziad Mercier', '59.0', 'IT', '7782.13', '19'],
#  ['2903', 'Ines Laurent', '38.0', 'IT', '6024.48', '8'],
#  ['2924', 'Noah Bernard', '27.0', 'IT', '5971.82', '9'],
#  ['2938', 'Alice Simon', '56.0', 'IT', '7501.6', '15'],
#  ['2970', 'Emma David', '49.0', 'IT', '6156.86', '12'],
#  ['2978', 'Tom Petit', '25.0', 'IT', '5500.9', '7'],
#  ['3075', 'Noah Dubois', '26.0', 'IT', '5827.24', '8'],
#  ['3087', 'Bob Andre', '25.0', 'IT', '5370.15', '7'],
#  ['3143', 'Alice Michel', '23.0', 'IT', '4749.9', '5'],
#  ['3167', 'Hugo Morel', '23.0', 'IT', '5008.01', '4'],
#  ['3168', 'Val Robert', '38.0', 'IT', '6416.92', '11'],
#  ['3208', 'Wassim Petit', '49.0', 'IT', '7348.3', '16'],
#  ['3224', 'Ines Bernard', '35.0', 'IT', '7232.43', '14'],
#  ['3257', 'Giulia Roux', '39.0', 'IT', '6375.67', '9'],
#  ['3258', 'Val Lefebvre', '51.0', 'IT', '7418.31', '16'],
#  ['3296', 'Pablo Simon', '35.0', 'IT', '6153.9', '10'],
#  ['3298', 'Ugo Dubois', '58.0', 'IT', '6361.15', '12'],
#  ['3302', 'Yara Martin', '35.0', 'IT', '5003.59', '4'],
#  ['3308', 'Rita Robert', '42.0', 'IT', '6140.34', '11'],
#  ['3343', 'Alice David', '37.0', 'IT', '5700.1', '8'],
#  ['3345', 'Bob Girard', '35.0', 'IT', '6330.84', '12'],
#  ['3372', 'Bob Laurent', '', 'IT', '6219.22', '9'],
#  ['3389', 'Ines Andre', '50.0', 'IT', '6172.34', '8'],
#  ['3404', 'Ines Girard', '50.0', 'IT', '5855.64', '9'],
#  ['3424', 'Katia Laurent', '25.0', 'IT', '5748.87', '7'],
#  ['3474', 'Rita David', '62.0', 'IT', '8155.86', '18'],
#  ['3483', 'Val Bernard', '36.0', 'IT', '5848.93', '8'],
#  ['3513', 'Bob Lefebvre', '46.0', 'IT', '6953.15', '12'],
#  ['3535', 'Bob Petit', '24.0', 'IT', '5064.04', '6'],
#  ['3552', 'Val Robert', '25.0', 'IT', '5888.03', '7'],
#  ['3563', 'Farid Fournier', '40.0', 'IT', '7208.69', '14'],
#  ['3591', 'Ines Andre', '29.0', 'IT', '6088.33', '10'],
#  ['3610', 'Hugo Martin', '62.0', 'IT', '7381.37', '17'],
#  ['3627', 'Wassim Robert', '64.0', 'IT', '7000.17', '17'],
#  ['3643', 'Farid Dubois', '19.0', 'IT', '4262.68', '1'],
#  ['3656', 'Tom Garcia', '25.0', 'IT', '5885.75', '7'],
#  ['3721', 'David Vincent', '63.0', 'IT', '6816.4', '13'],
#  ['3722', 'Liam Richard', '49.0', 'IT', '6668.57', '12'],
#  ['3757', 'David David', '27.0', 'IT', '5004.34', '6'],
#  ['3802', 'Sara Girard', '64.0', 'IT', '9614.92', '25'],
#  ['3819', 'Claire Lefebvre', '39.0', 'IT', '5964.66', '11'],
#  ['3854', 'Claire Roux', '48.0', 'IT', '5069.44', '6'],
#  ['3887', 'Wassim Vincent', '19.0', 'IT', '4113.42', '1'],
#  ['3913', 'Pablo Bertrand', '58.0', 'IT', '6723.28', '14'],
#  ['3924', 'Omar Bernard', '52.0', 'IT', '6581.48', '12'],
#  ['3925', 'Maya Bertrand', '38.0', 'IT', '5925.58', '9'],
#  ['3931', 'Giulia Fournier', '25.0', 'IT', '5506.81', '7'],
#  ['3939', 'Sara Laurent', '61.0', 'IT', '10020.2', '26'],
#  ['3946', 'Xia Robert', '46.0', 'IT', '6653.92', '13'],
#  ['3951', 'Ziad Bertrand', '53.0', 'IT', '6420.95', '13'],
#  ['3967', 'Katia Robert', '59.0', 'IT', '7235.24', '13'],
#  ['4002', 'Sara Richard', '44.0', 'IT', '5776.28', '6'],
#  ['4031', 'Farid Andre', '54.0', 'IT', '6633.18', '14'],
#  ['4035', 'Bob Laurent', '49.0', 'IT', '7282.14', '14'],
#  ['4046', 'Farid Bertrand', '30.0', 'IT', '5687.39', '8'],
#  ['4047', 'Noah Vincent', '49.0', 'IT', '8256.08', '18'],
#  ['4059', 'Farid Lefebvre', '', 'IT', '6213.76', '11'],
#  ['4094', 'Liam Lefebvre', '24.0', 'IT', '5380.28', '6'],
#  ['4112', 'Qi Moreau', '35.0', 'IT', '5939.86', '10'],
#  ['4140', 'David Girard', '28.0', 'IT', '5288.6', '7'],
#  ['4249', 'Jamal David', '23.0', 'IT', '5118.77', '5'],
#  ['4283', 'Alice David', '50.0', 'IT', '8254.3', '18'],
#  ['4315', 'Liam Petit', '19.0', 'IT', '4232.17', '1'],
#  ['4327', 'Omar Michel', '29.0', 'IT', '6282.99', '11'],
#  ['4369', 'Giulia Girard', '34.0', 'IT', '7153.0', '12'],
#  ['4371', 'Ines Mercier', '44.0', 'IT', '6481.66', '10'],
#  ['4470', 'Farid Simon', '44.0', 'IT', '6741.91', '12'],
#  ['4474', 'Qi Petit', '26.0', 'IT', '6054.41', '8'],
#  ['4508', 'David Richard', '54.0', 'IT', '7157.4', '14'],
#  ['4558', 'Maya Roux', '58.0', 'IT', '7105.01', '15'],
#  ['4564', 'Claire Garcia', '46.0', 'IT', '7135.53', '15'],
#  ['4623', 'Maya Bertrand', '59.0', 'IT', '7417.35', '15'],
#  ['4651', 'Emma Fournier', '44.0', 'IT', '7064.54', '13'],
#  ['4697', 'Jamal Morel', '32.0', 'IT', '5641.69', '8'],
#  ['4719', 'Xia Laurent', '47.0', 'IT', '6706.63', '12'],
#  ['4741', 'Omar Morel', '42.0', 'IT', '6162.58', '10'],
#  ['4754', 'Qi Petit', '25.0', 'IT', '5776.23', '6'],
#  ['4765', 'Yara Richard', '48.0', 'IT', '6864.73', '14'],
#  ['4826', 'Ziad Lefebvre', '38.0', 'IT', '6340.29', '12'],
#  ['4860', 'Emma Richard', '59.0', 'IT', '', '18'],
#  ['4869', 'Maya Bertrand', '55.0', 'IT', '6421.18', '11'],
#  ['4889', 'Bob Fournier', '28.0', 'IT', '5683.48', '7'],
#  ['4892', 'Ugo Simon', '64.0', 'IT', '8177.14', '17'],
#  ['4897', 'David Vincent', '52.0', 'IT', '6861.85', '14'],
#  ['4902', 'David Roux', '55.0', 'IT', '5633.46', '9'],
#  ['4921', 'Qi Richard', '47.0', 'IT', '7176.35', '14'],
#  ['4945', 'Tom Robert', '22.0', 'IT', '5105.51', '3'],
#  ['4975', 'Katia Lefebvre', '', 'IT', '7035.08', '12'],
#  ['4995', 'Bob Laurent', '55.0', 'IT', '7356.58', '15'],
#  ['5014', 'Bob Petit', '49.0', 'IT', '6895.58', '12'],
#  ['5053', 'Katia Andre', '', 'IT', '6692.07', '11'],
#  ['5081', 'Wassim Garcia', '22.0', 'IT', '4779.82', '4'],
#  ['5115', 'Rita Martin', '38.0', 'IT', '6305.82', '10'],
#  ['5126', 'Ziad Lefebvre', '52.0', 'IT', '6087.58', '10'],
#  ['5152', 'Ugo Bertrand', '64.0', 'IT', '6762.71', '13'],
#  ['5155', 'Qi Girard', '29.0', 'IT', '5943.05', '10'],
#  ['5236', 'Alice Fournier', '45.0', 'IT', '6913.08', '14'],
#  ['5253', 'Ziad Martin', '29.0', 'IT', '5102.55', '5'],
#  ['5283', 'Farid Moreau', '21.0', 'IT', '4522.61', '3'],
#  ['5291', 'Omar Andre', '38.0', 'IT', '5865.8', '8'],
#  ['5306', 'Hugo Fournier', '26.0', 'IT', '6058.16', '8'],
#  ['5357', 'Wassim Martin', '54.0', 'IT', '7365.44', '14'],
#  ['5373', 'Ines Michel', '60.0', 'IT', '7048.33', '14'],
#  ['5388', 'Ziad Fournier', '41.0', 'IT', '7623.28', '14'],
#  ['5389', 'Katia Dubois', '46.0', 'IT', '5363.55', '6'],
#  ['5415', 'Ugo Moreau', '60.0', 'IT', '6564.19', '12'],
#  ['5433', 'Omar Bertrand', '64.0', 'IT', '7114.5', '13'],
#  ['5473', 'Jamal Andre', '62.0', 'IT', '7983.97', '17'],
#  ['5489', 'Tom Durand', '24.0', 'IT', '3855.86', '1'],
#  ['5522', 'Maya Girard', '', 'IT', '7275.43', '15'],
#  ['5547', 'Rita Lefebvre', '53.0', 'IT', '7508.08', '17'],
#  ['5620', 'Ziad Mercier', '21.0', 'IT', '4108.43', '3'],
#  ['5640', 'Xia Durand', '39.0', 'IT', '', '11'],
#  ['5652', 'Val Vincent', '29.0', 'IT', '5656.91', '7'],
#  ['5663', 'Val Simon', '38.0', 'IT', '6823.25', '10'],
#  ['5709', 'Bob Mercier', '47.0', 'IT', '7251.57', '14'],
#  ['5710', 'Sara Richard', '37.0', 'IT', '5674.59', '8'],
#  ['5742', 'Sara Fournier', '41.0', 'IT', '8100.34', '19'],
#  ['5756', 'Maya Bernard', '50.0', 'IT', '7140.42', '15'],
#  ['5759', 'Ines Lefebvre', '29.0', 'IT', '5701.51', '8'],
#  ['5833', 'David Garcia', '61.0', 'IT', '8482.22', '21'],
#  ['5868', 'Qi Bernard', '19.0', 'IT', '4303.73', '1'],
#  ['5883', 'Liam Moreau', '32.0', 'IT', '6260.74', '10'],
#  ['5898', 'Qi David', '30.0', 'IT', '5631.25', '7'],
#  ['5938', 'Pablo Roux', '29.0', 'IT', '4890.47', '5'],
#  ['5951', 'Emma Morel', '34.0', 'IT', '6437.79', '12'],
#  ['6016', 'Tom Martin', '30.0', 'IT', '5176.54', '6'],
#  ['6079', 'Val Laurent', '46.0', 'IT', '7356.85', '17'],
#  ['6088', 'Pablo Andre', '51.0', 'IT', '6886.59', '14'],
#  ['6092', 'Sara Martin', '64.0', 'IT', '7764.21', '19'],
#  ['6146', 'Yara Richard', '42.0', 'IT', '5798.23', '9'],
#  ['6163', 'Liam Roux', '42.0', 'IT', '6821.76', '12'],
#  ['6177', 'Sara Petit', '43.0', 'IT', '7138.02', '15'],
#  ['6238', 'Wassim Mercier', '64.0', 'IT', '8783.41', '18'],
#  ['6348', 'Maya Lefebvre', '26.0', 'IT', '5607.5', '8'],
#  ['6349', 'Pablo Michel', '22.0', 'IT', '4945.33', '4'],
#  ['6412', 'Tom Andre', '48.0', 'IT', '7729.31', '18'],
#  ['6527', 'Val Andre', '25.0', 'IT', '4921.44', '7'],
#  ['6540', 'Liam Martin', '35.0', 'IT', '6813.51', '12'],
#  ['6543', 'Emma Lefebvre', '57.0', 'IT', '7058.3', '14'],
#  ['6613', 'Qi Durand', '53.0', 'IT', '7889.24', '14'],
#  ['6635', 'Wassim Dubois', '49.0', 'IT', '6356.2', '11'],
#  ['6646', 'Wassim Andre', '62.0', 'IT', '7017.36', '15'],
#  ['6655', 'Jamal Michel', '44.0', 'IT', '6635.62', '15'],
#  ['6692', 'Hugo Moreau', '62.0', 'IT', '6713.94', '14'],
#  ['6713', 'Xia Bernard', '45.0', 'IT', '7847.25', '16'],
#  ['6735', 'Claire Durand', '38.0', 'IT', '5271.67', '7'],
#  ['6746', 'Liam Lefebvre', '36.0', 'IT', '4747.14', '8'],
#  ['6770', 'Omar Vincent', '19.0', 'IT', '4733.06', '1'],
#  ['6811', 'Val Laurent', '63.0', 'IT', '8539.76', '23'],
#  ['6830', 'Bob Roux', '25.0', 'IT', '4174.8', '1'],
#  ['6875', 'Bob Mercier', '61.0', 'IT', '9312.44', '24'],
#  ['6888', 'Ugo Roux', '48.0', 'IT', '6152.03', '11'],
#  ['6928', 'Omar Bernard', '51.0', 'IT', '6367.0', '13'],
#  ['6934', 'Hugo Robert', '22.0', 'IT', '4896.6', '4'],
#  ['6948', 'Hugo Mercier', '19.0', 'IT', '4141.2', '1'],
#  ['6993', 'Wassim Michel', '27.0', 'IT', '5833.34', '9'],
#  ['6995', 'Katia Lefebvre', '34.0', 'IT', '5461.02', '8'],
#  ['7031', 'Alice Petit', '49.0', 'IT', '7019.21', '14'],
#  ['7032', 'Jamal David', '53.0', 'IT', '8421.46', '16'],
#  ['7045', 'Ziad Martin', '37.0', 'IT', '5730.24', '7'],
#  ['7079', 'Sara Roux', '24.0', 'IT', '4704.8', '6'],
#  ['7085', 'Farid Moreau', '31.0', 'IT', '6145.27', '11'],
#  ['7088', 'Yara Roux', '60.0', 'IT', '8551.43', '20'],
#  ['7100', 'Pablo Petit', '62.0', 'IT', '7317.57', '16'],
#  ['7180', 'Jamal Bernard', '61.0', 'IT', '7567.42', '17'],
#  ['7188', 'Tom Bertrand', '42.0', 'IT', '6802.0', '11'],
#  ['7194', 'Giulia Michel', '46.0', 'IT', '7309.57', '14'],
#  ['7200', 'Hugo Michel', '46.0', 'IT', '7202.14', '14'],
#  ['7214', 'Hugo Michel', '59.0', 'IT', '8007.03', '18'],
#  ['7233', 'Wassim Simon', '29.0', 'IT', '5508.5', '6'],
#  ['7340', 'Pablo Richard', '38.0', 'IT', '7185.18', '14'],
#  ['7377', 'Bob Michel', '22.0', 'IT', '5137.56', '4'],
#  ['7488', 'Val Laurent', '63.0', 'IT', '7440.09', '15'],
#  ['7522', 'Emma Garcia', '55.0', 'IT', '7521.4', '17'],
#  ['7554', 'Claire Andre', '20.0', 'IT', '', '2'],
#  ['7587', 'Tom Simon', '23.0', 'IT', '4901.54', '5'],
#  ['7661', 'Yara David', '23.0', 'IT', '4889.39', '5'],
#  ['7663', 'Noah Durand', '49.0', 'IT', '6998.11', '13'],
#  ['7665', 'Alice Mercier', '47.0', 'IT', '6166.47', '11'],
#  ['7671', 'Jamal Vincent', '26.0', 'IT', '5154.38', '6'],
#  ['7674', 'Alice Simon', '30.0', 'IT', '4985.88', '5'],
#  ['7712', 'Katia Martin', '57.0', 'IT', '6906.12', '13'],
#  ['7732', 'Ines Andre', '29.0', 'IT', '5775.94', '9'],
#  ['7739', 'Claire Bernard', '55.0', 'IT', '7778.2', '15'],
#  ['7771', 'Claire Michel', '21.0', 'IT', '3903.44', '0'],
#  ['7797', 'Wassim Andre', '51.0', 'IT', '8408.22', '17'],
#  ['7864', 'Giulia Richard', '21.0', 'IT', '4209.8', '3'],
#  ['7878', 'Qi Robert', '45.0', 'IT', '6916.6', '12'],
#  ['7902', 'Xia Moreau', '36.0', 'IT', '', '8'],
#  ['7940', 'Claire Lefebvre', '37.0', 'IT', '5905.61', '11'],
#  ['7945', 'Omar Dubois', '26.0', 'IT', '4659.14', '4'],
#  ['7950', 'Xia Lefebvre', '26.0', 'IT', '5609.2', '7'],
#  ['8020', 'Yara Simon', '46.0', 'IT', '5450.89', '9'],
#  ['8033', 'Qi Vincent', '42.0', 'IT', '6965.2', '14'],
#  ['8099', 'Alice Michel', '45.0', 'IT', '6632.66', '12'],
#  ['8103', 'Yara Moreau', '55.0', 'IT', '7519.32', '17'],
#  ['8108', 'Rita Robert', '24.0', 'IT', '5451.17', '6'],
#  ['8126', 'Hugo Petit', '64.0', 'IT', '6380.12', '13'],
#  ['8135', 'Farid Richard', '50.0', 'IT', '6962.95', '14'],
#  ['8142', 'Ines Vincent', '19.0', 'IT', '4589.64', '1'],
#  ['8221', 'Tom Mercier', '30.0', 'IT', '5265.1', '6'],
#  ['8233', 'Emma Lefebvre', '61.0', 'IT', '8021.97', '20'],
#  ['8240', 'Ugo Vincent', '47.0', 'IT', '7080.77', '13'],
#  ['8281', 'Noah Garcia', '61.0', 'IT', '7545.37', '15'],
#  ['8313', 'Sara Durand', '55.0', 'IT', '7444.45', '15'],
#  ['8354', 'Maya David', '28.0', 'IT', '4271.94', '3'],
#  ['8362', 'Ugo Bernard', '', 'IT', '6261.0', '10'],
#  ['8368', 'Noah Durand', '59.0', 'IT', '7886.62', '17'],
#  ['8380', 'Maya Bertrand', '58.0', 'IT', '7963.82', '18'],
#  ['8383', 'Ines Bernard', '38.0', 'IT', '6559.41', '12'],
#  ['8412', 'Maya Garcia', '46.0', 'IT', '7221.23', '15'],
#  ['8423', 'Claire Bertrand', '31.0', 'IT', '6049.07', '9'],
#  ['8447', 'Qi Simon', '36.0', 'IT', '5824.43', '11'],
#  ['8481', 'Emma Vincent', '37.0', 'IT', '5586.45', '8'],
#  ['8509', 'Noah Petit', '64.0', 'IT', '7710.85', '19'],
#  ['8554', 'Yara Roux', '26.0', 'IT', '5579.93', '7'],
#  ['8575', 'Liam Michel', '', 'IT', '6171.21', '8'],
#  ['8614', 'Claire Andre', '23.0', 'IT', '5130.35', '5'],
#  ['8691', 'Hugo Mercier', '22.0', 'IT', '4668.13', '1'],
#  ['8716', 'Qi Michel', '46.0', 'IT', '7128.16', '14'],
#  ['8721', 'Claire Roux', '37.0', 'IT', '5606.17', '8'],
#  ['8736', 'Val Bertrand', '46.0', 'IT', '7276.62', '14'],
#  ['8801', 'Maya Vincent', '57.0', 'IT', '7630.55', '16'],
#  ['8804', 'Emma Fournier', '61.0', 'IT', '', '19'],
#  ['8859', 'Katia David', '31.0', 'IT', '', '10'],
#  ['8908', 'Pablo Richard', '', 'IT', '6861.51', '14'],
#  ['8968', 'Farid Richard', '33.0', 'IT', '5044.83', '4'],
#  ['8988', 'Wassim Moreau', '28.0', 'IT', '6296.76', '10'],
#  ['9010', 'Noah Bertrand', '57.0', 'IT', '8475.83', '20'],
#  ['9040', 'Tom Durand', '33.0', 'IT', '5656.39', '8'],
#  ['9119', 'Pablo Petit', '36.0', 'IT', '6816.8', '12'],
#  ['9120', 'Wassim Petit', '34.0', 'IT', '4529.64', '5'],
#  ['9144', 'Emma Morel', '31.0', 'IT', '4555.35', '6'],
#  ['9169', 'Ugo Andre', '54.0', 'IT', '6965.07', '11'],
#  ['9194', 'Noah Garcia', '26.0', 'IT', '5086.24', '6'],
#  ['9222', 'Claire Laurent', '24.0', 'IT', '3606.36', '1'],
#  ['9236', 'Katia Simon', '47.0', 'IT', '5204.44', '7'],
#  ['9239', 'Omar Simon', '64.0', 'IT', '7696.68', '15'],
#  ['9243', 'Sara Lefebvre', '58.0', 'IT', '7612.8', '15'],
#  ['9256', 'Bob Moreau', '30.0', 'IT', '5940.09', '9'],
#  ['9322', 'Wassim Michel', '', 'IT', '5703.32', '7'],
#  ['9343', 'Ugo Martin', '61.0', 'IT', '', '24'],
#  ['9359', 'Val Moreau', '39.0', 'IT', '5347.54', '8'],
#  ['9370', 'Val Dubois', '24.0', 'IT', '5463.79', '6'],
#  ['9381', 'Wassim Vincent', '26.0', 'IT', '5437.39', '8'],
#  ['9411', 'Wassim Mercier', '28.0', 'IT', '5160.46', '6'],
#  ['9449', 'Emma Laurent', '25.0', 'IT', '5206.13', '7'],
#  ['9526', 'Farid Girard', '30.0', 'IT', '', '4'],
#  ['9537', 'Katia Robert', '35.0', 'IT', '5893.65', '8'],
#  ['9552', 'Farid Martin', '19.0', 'IT', '4374.65', '1'],
#  ['9553', 'Claire Bertrand', '57.0', 'IT', '7324.72', '15'],
#  ['9554', 'Xia Moreau', '29.0', 'IT', '6263.78', '7'],
#  ['9555', 'Bob Fournier', '42.0', 'IT', '6605.05', '11'],
#  ['9623', 'Liam Andre', '49.0', 'IT', '8399.99', '20'],
#  ['9679', 'Maya Durand', '30.0', 'IT', '5884.81', '11'],
#  ['9720', 'Claire Andre', '35.0', 'IT', '7259.31', '12'],
#  ['9789', 'Giulia Robert', '22.0', 'IT', '4412.13', '2'],
#  ['9798', 'Omar Richard', '33.0', 'IT', '6849.29', '15'],
#  ['9807', 'Claire Dubois', '30.0', 'IT', '5357.85', '7'],
#  ['9822', 'Hugo Roux', '42.0', 'IT', '5418.41', '6'],
#  ['9826', 'David Simon', '52.0', 'IT', '6567.65', '11'],
#  ['9828', 'Bob Fournier', '64.0', 'IT', '9079.02', '21'],
#  ['9847', 'Ugo David', '27.0', 'IT', '5116.9', '6'],
#  ['9862', 'Hugo Fournier', '31.0', 'IT', '6059.81', '9'],
#  ['9916', 'Ines Richard', '21.0', 'IT', '4514.98', '3'],
#  ['9969', 'Yara Simon', '43.0', 'IT', '6707.46', '10']]

# %% [markdown]
# ## 8. Approfondir

# %% [markdown]
# Ce notebook propose une **introduction pratique et progressive** à Apache Spark et PySpark.
# Il ne couvre pas toutes les subtilités du framework, notamment celles liées à l’**optimisation des performances**, la **gestion des clusters**, ou les **fonctionnalités avancées**, MLlib, ou Structured Streaming.
#
# Pour compléter votre apprentissage, il est **fortement recommandé de poursuivre l’exploration** à travers d'autres ressources.\
# Il existe **de nombreuses ressources de qualité disponibles en ligne**, il suffit de chercher un peu pour trouver des explications, tutoriels et exemples adaptés à votre niveau.
#
# #### Ressources officielles
# - [Documentation officielle de Spark](https://spark.apache.org/docs/latest/) — la source principale pour comprendre les modules (SQL, MLlib, Streaming, GraphX).
# - [API PySpark sur spark.apache.org](https://spark.apache.org/docs/latest/api/python/) — référence complète des fonctions disponibles.
# - [Apache Spark sur GitHub](https://github.com/apache/spark) — pour explorer le code source et les évolutions du projet.
#
# #### Tutoriels et cours gratuits
# - [Spark Tutorial (DataCamp)](https://www.datacamp.com/tutorial/pyspark-tutorial-getting-started-with-pyspark) — bonnes bases pour pratiquer avec PySpark.
# - [YouTube – “Apache Spark Full Course” by Simplilearn](https://www.youtube.com/watch?v=_C8kWso4ne4) — formation vidéo complète et vulgarisée.
